# %% [markdown]
# #1. Downloading and Annotating Data

# %%
import librosa
import pandas as pd
import numpy as np
from IPython.lib.display import Audio
from matplotlib import pyplot as plt
import multiprocessing
import scipy.signal
from scipy import signal
import torch
import glob

# %%
! rm -r data
# Out:
# rm: cannot remove 'data': No such file or directory

# %% [markdown]
# Downloading the data

# %%
# !mkdir data
# !cd data && wget https://archive.org/download/dog-barks-raw/Dog%20Bark%20Data.zip
# !cd data && unzip -q "Dog Bark Data.zip"
# !ls data/"Dog Bark Data"/Dog
# Out:
# --2025-04-06 01:02:06--  https://archive.org/download/dog-barks-raw/Dog%20Bark%20Data.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia801806.us.archive.org/7/items/dog-barks-raw/Dog%20Bark%20Data.zip [following]
# --2025-04-06 01:02:08--  https://ia801806.us.archive.org/7/items/dog-barks-raw/Dog%20Bark%20Data.zip
# Resolving ia801806.us.archive.org (ia801806.us.archive.org)... 207.241.230.176
# Connecting to ia801806.us.archive.org (ia801806.us.archive.org)|207.241.230.176|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943878068 (1.8G) [application/zip]
# Saving to: ‘Dog Bark Data.zip’
#
# Dog Bark Data.zip   100%[===================>]   1.81G  19.3MB/s    in 5m 7s
#
# 2025-04-06 01:07:15 (6.04 MB/s) - ‘Dog Bark Data.zip’ saved [1943878068/1943878068]

# %% [markdown]
# Annotating the data

# %%
paths = glob.glob('data/**/**/**/**/*.aif') + glob.glob('data/**/**/**/**/*.wav')

# %%
# This is the number of audiofiles
len(paths)
# Out:
# 720

# %%
# !mkdir data/audio

# %%
# Copied straight from the Earth Species github
import re
import shutil

filename = []
name = []
context = []

for path in paths:
    try:
        n, session, c, session_sequence, *_ = re.findall('(\w+)', path.split('/')[-1])
        if c not in ['A', 'C', 'P']:
            n, c, *_ = re.findall('(\w+)', path.split('/')[-1])
            if c not in ['A', 'C', 'P']:
                n, _, c = re.findall('(\w+)', path.split('/')[-1])
                c = c[0]
                if c not in ['A', 'C', 'P']: continue
    except:
        continue
    shutil.copy(path, 'data/audio')
    filename.append(path.split('/')[-1])
    name.append(n)
    context.append(c)

# %%
# Copied from Earth Species github
# This code parses the file names to extract the labels
fix_names = {
    'Freid3': 'Freid',
    'Freid4': 'Freid',
    'Fried': 'Freid',
    'Keri3': 'Keri',
    'Kerik': 'Keri',
    'Zzoe': 'Zoe',
    'luke': 'Luke',
    'Louis': 'Louie'

}

name = [n if n not in fix_names.keys() else fix_names[n] for n in name]

age_map = {
    'Farley': 3,
    'Freid': 5,
    'Keri': 4,
    'Louie': 2,
    'Luke': 5,
    'Mac': 5,
    'Roodie': 12,
    'Rudy': 11,
    'Siggy': 11,
    'Zoe': 7
}

weight_map = {
    'Farley': 25,
    'Freid': 6,
    'Keri': 34,
    'Louie': 19,
    'Luke': 25,
    'Mac': 34,
    'Roodie': 18,
    'Rudy': 32,
    'Siggy': 36,
    'Zoe': 16
}

sex_map = {
    'Farley': 'male',
    'Freid': 'male',
    'Keri': 'female',
    'Louie': 'male',
    'Luke': 'male',
    'Mac': 'male',
    'Roodie': 'male',
    'Rudy': 'male',
    'Siggy': 'male',
    'Zoe': 'female'
}

breed_map = {
    'Farley': 'Australian shepherd',
    'Freid': 'Dachsund',
    'Keri': 'Labrador mix',
    'Louie': 'Springer spaniel',
    'Luke': 'Australian shepherd',
    'Mac': 'German shorthair pointer',
    'Roodie': 'Australian cattle dog',
    'Rudy': 'German shorthair pointer',
    'Siggy': 'German shorthair pointer',
    'Zoe': 'Australian cattle dog'
}

age, weight, sex, breed = zip(*[(age_map[n], weight_map[n], sex_map[n], breed_map[n]) for n in name])

# %%
# Copied from Earth Species
# Creates a dataframe with all the different labels corresponding to each bark file
import pandas as pd

anno = pd.DataFrame(data={
    'filename': filename,
    'name': name,
    'context': context,
    'age': age,
    'weight': weight,
    'sex': sex,
    'breed': breed
})
context_map = {
    'A': 'aggression',
    'C': 'contact',
    'P': 'play'
}

anno.context = anno.context.apply(lambda c: context_map[c])

# %%
anno.head()
# Out:
#            filename   name     context  age  weight   sex  \
# 0  Siggy-5-P-5d.aif  Siggy        play   11      36  male
# 1  Siggy-5-C-5a.aif  Siggy     contact   11      36  male
# 2   Siggy-5-A-5.aif  Siggy  aggression   11      36  male
# 3  Siggy-5-P-5b.aif  Siggy        play   11      36  male
# 4  Siggy-5-C-5c.aif  Siggy     contact   11      36  male
#
#                       breed
# 0  German shorthair pointer
# 1  German shorthair pointer
# 2  German shorthair pointer
# 3  German shorthair pointer
# 4  German shorthair pointer

# %%
# Drop empty file
anno = anno[anno.filename != 'Siggy-4-A-4.aif']
# Create a csv file of the annotation
anno.to_csv('data/annotations.csv', index=False)

# %% [markdown]
# # 2. Generating Spectrograms

# %%
# !cd ..
anno = pd.read_csv('data/annotations.csv')

audio = []

for _, row in anno.iterrows():
    recording, sr = librosa.load(f'data/audio/{row.filename}', sr=None)
    audio.append(recording)

anno['audio'] = audio

# %%
anno.head()
# Out:
#            filename   name     context  age  weight   sex  \
# 0  Siggy-5-P-5d.aif  Siggy        play   11      36  male
# 1  Siggy-5-C-5a.aif  Siggy     contact   11      36  male
# 2   Siggy-5-A-5.aif  Siggy  aggression   11      36  male
# 3  Siggy-5-P-5b.aif  Siggy        play   11      36  male
# 4  Siggy-5-C-5c.aif  Siggy     contact   11      36  male
#
#                       breed                                              audio
# 0  German shorthair pointer  [0.00024414062, 0.00039672852, 0.00030517578, ...
# 1  German shorthair pointer  [-0.00015258789, -6.1035156e-05, -0.0001678466...
# 2  German shorthair pointer  [0.0005950928, 0.00012207031, -0.00048828125, ...
# 3  German shorthair pointer  [-0.003540039, 0.0018310547, 0.0019836426, 0.0...
# 4  German shorthair pointer  [0.000289917, 0.0002746582, 0.00039672852, 7.6...

# %%
sample_rate = 44100
def audio_to_spec(audio, sample_rate):
  # Compute spectrogram using SciPy
  freqs, times, Sx = signal.spectrogram(audio, fs=sample_rate)

  # Limit the frequency range to about 10kHz to limit computation
  freqs, Sx = freqs[:59], Sx[:59]

  # Convert to decibels (log-scale)
  epsilon = 1e-10  # Small constant to avoid log(0)
  Sx = 10 * np.log10(Sx + epsilon)

  return times, freqs, Sx

# %%
def plot_spectrogram(audio, sample_rate, title="Spectrogram"):
    times, freqs, Sx = audio_to_spec(audio, sample_rate)

    plt.figure(figsize=(10, 5))
    plt.pcolormesh(times, freqs / 1000, Sx, cmap='viridis')  # Convert to kHz
    plt.xlabel('Time [s]')
    plt.ylabel('Frequency [kHz]')
    plt.title(title)
    plt.colorbar(label='Power (dB)')
    plt.show()

# %%
# example
example_audio = anno["audio"][10]
plot_spectrogram(example_audio, sample_rate)

# %% [markdown]
# # 3. Segmenting Barks Using Clustering

# %% [markdown]
# Function to visualize the clustering

# %%
# Function to visualize bark segments
def visualize_bark_segments(audio_path, bark_groups, sample_rate, y):
    # Time axis
    time_axis = np.linspace(0, len(y) / sample_rate, num=len(y))

    plt.figure(figsize=(12, 5))
    librosa.display.waveshow(y, sr=sample_rate, alpha=0.5, color='gray', label="Waveform")

    # Highlight merged bark segments
    for start, end in bark_groups:
        plt.axvspan(start * (1), end * (1), color='red', alpha=0.3)  # Convert segment index to seconds

    plt.xlabel("Time (seconds)")
    plt.ylabel("Amplitude")
    plt.title(f"Bark Segmentation Visualization for {audio_path}")
    plt.legend(["Legend", "Waveform", "Bark (Red)"])
    plt.show()

# %% [markdown]
# Detecting barks using k-means clustering.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import soundfile as sf
import os

frame_length = 2048
hop_length = 512

# Since we want segments all of 1 second, segment length equals sampling rate
segment_length_s = 0.5
segment_length = int(sample_rate*segment_length_s)

# Make folder to store extracted barks
output_folder = "segmented_barks"
os.makedirs(output_folder, exist_ok=True)

all_labels = []
plotted = False
for file_idx, a in enumerate(audio):
  # Split audio into 1 second chunks
  segments = librosa.util.frame(a, frame_length=segment_length, hop_length=segment_length).T

  # Extract relevant features from each segment, in this case RMS
  features = []
  # store rms values for label correction
  rms_values = []
  for segment in segments:
    zcr = np.mean(librosa.feature.zero_crossing_rate(segment))  # Mean ZCR
    rms = np.mean(librosa.feature.rms(y=segment))  # Mean Energy
    centroid = np.mean(librosa.feature.spectral_centroid(y=segment, sr=sample_rate))  # Spectral Centroid
    mfcc = np.mean(librosa.feature.mfcc(y=segment, sr=sample_rate, n_mfcc=13), axis=1)  # MFCCs
    feature_vector = np.hstack([zcr, rms, centroid, mfcc])
    features.append(feature_vector)
    rms_values.append(rms)
  features = np.array(features)
  rms_values = np.array(rms_values)

  # Normalize
  scaler = StandardScaler()
  features_scaled = scaler.fit_transform(features)

  # K-Means
  kmeans = KMeans(n_clusters=2, random_state=42)
  labels = kmeans.fit_predict(features_scaled)

  # Label correction, 1 represents bark
  # This is done by assuming that a higher RMS => bark
  rms_per_cluster = [np.mean(rms_values[labels == cluster]) for cluster in np.unique(labels)]
  bark_cluster = np.argmax(rms_per_cluster)  # Identify high-energy cluster
  labels = np.array([1 if label == bark_cluster else 0 for label in labels])
  all_labels.append(labels)

  # Merge Consecutive Bark Segments -------------------
  # This is so barks can be variable in length
  bark_groups = []
  start_idx = None

  for i, label in enumerate(labels):
      if label == 1:
          if start_idx is None:
              start_idx = i  # Start of a new bark
      else:
          if start_idx is not None:
              bark_groups.append((start_idx, i))  # End previous bark
              start_idx = None
  if start_idx is not None:
      bark_groups.append((start_idx, len(labels)))

  # Extract and save the merged bark segments ----------
  for bark_id, (start, end) in enumerate(bark_groups):
        start_sample = start * segment_length
        end_sample = end * segment_length
        bark_audio = a[start_sample:end_sample]

        sf.write(f"{output_folder}/bark_{file_idx}_{bark_id}.wav", bark_audio, sample_rate)

  #--------------------------------------------------- Plot ------------------------------------------
  if not plotted:
    visualize_bark_segments(f"{output_folder}/bark_{file_idx}_{bark_id}.wav", bark_groups, segment_length, a)
    plotted = True

# %% [markdown]
# Now we have a folder called `segmented_barks` that contains all the segmented bark audio files. The files are named: "bark\_\<file-num\>\_\<seg-num\>" where \<file-num\> corresponds to each original recording and \<seg-num\> numbers each segment in each recording.

# %%
max_length = 0
bark_durations = [] # durations of barks in seconds

for file in os.listdir("segmented_barks"):
  a, sr = librosa.load(os.path.join("segmented_barks", file), sr=None)
  cur_length = len(a)
  bark_durations.append(cur_length / sample_rate)
  if cur_length > max_length:
    max_length = cur_length

print(f"The longest bark is {max_length / sample_rate:.2f} seconds.")
# Out:
# The longest bark is 22.00 seconds.

# %%
# Plot histogram
plt.figure(figsize=(10, 4))
plt.hist(bark_durations, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Bark Duration (seconds)")
plt.ylabel("Frequency")
plt.title("Distribution of Bark Durations")
plt.grid(True)
plt.show()

# %% [markdown]
# We can see that there are a very small amount of barks that are larger than 4 seconds. Let's remove these files.

# %%
target_duration = 4 # in seconds
target_length = target_duration * sample_rate

for file in os.listdir("segmented_barks"):
  file_path = os.path.join("segmented_barks", file)

  # Load the audio file
  y, sr = librosa.load(file_path, sr=None)
  duration = len(y) / sr  # Convert samples to seconds

  # Remove file if it exceeds max_duration
  if duration > target_duration:
    os.remove(file_path)
    # Uncomment to show which files are removed
    # print(f"Removed: {file} (Duration: {duration:.2f}s)")
  # Otherwise, pad the file to be 4 seconds
  elif duration < target_duration:
    padded_y = np.pad(y, (0, target_length - len(y)), mode='constant')
    sf.write(file_path, padded_y, sample_rate)
    # Uncomment to show which files are padded
    # print(f"Padded: {file} to 4 seconds")

# %% [markdown]
# Add segmented_barks to the old dataframe.

# %%
# Create a new DataFrame for segmented barks
bark_data = []

# Iterate over segmented bark files
for file in os.listdir("segmented_barks"):
  # Extract the file index from the filename (assuming format "bark_<file-num>_<seg-num>.wav")
  file_index = int(file.split("_")[1])

  # Find the original row using the file index
  # Recall the old dataframe is called anno
  row = anno.iloc[file_index].to_dict()

  # Update the "single_bark" column with the segmented file path
  row["single_bark"] = os.path.join("segmented_barks", file)

  # Append updated row to the new dataset
  bark_data.append(row)

# Create a new DataFrame with the segmented barks
df_barks = pd.DataFrame(bark_data)
df_barks = df_barks.drop(columns=["audio"])

df_barks.head()
# Out:
#                   filename    name     context  age  weight     sex  \
# 0         Siggy-5-C-5b.aif   Siggy     contact   11      36    male
# 1  Zoe-6-P-5a(7_16_00).aif     Zoe        play    7      16  female
# 2          Mac-10-A-10.aif     Mac  aggression    5      34    male
# 3          Rudy-1-A-1a.aif    Rudy  aggression   11      32    male
# 4        Roodie-7-P-7b.aif  Roodie        play   12      18    male
#
#                       breed                     single_bark
# 0  German shorthair pointer    segmented_barks/bark_6_1.wav
# 1     Australian cattle dog  segmented_barks/bark_477_0.wav
# 2  German shorthair pointer  segmented_barks/bark_148_5.wav
# 3  German shorthair pointer  segmented_barks/bark_166_1.wav
# 4     Australian cattle dog  segmented_barks/bark_676_4.wav

# %% [markdown]
# Data preprocessing is complete. The files that will be useful in training a model are `segmented_barks`, which is a folder containing all single bark audio files, and `updated_dataset.csv`, which is a csv with each segmented bark with its corresonding labels.

# %%
# Save the updated dataset
df_barks.to_csv("updated_dataset.csv", index=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset, random_split
import pandas as pd
import numpy as np
import os
from scipy import signal

class BarkDataset(Dataset):
    def __init__(self, csv_path, audio_folder, transform=None):
        self.data = pd.read_csv(csv_path)
        self.audio_folder = audio_folder
        self.transform = transform
        self.label_map = {"Farley": 0, "Freid": 1, "Keri": 2, "Louie": 3, "Luke": 4, "Mac": 5, "Roodie": 6, "Rudy": 7, "Siggy": 8, "Zoe": 9}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        audio_path = os.path.join(self.audio_folder, os.path.basename(row["single_bark"]))
        y, sr = librosa.load(audio_path, sr=None)

        # Compute spectrogram
        freqs, times, Sx = signal.spectrogram(y, fs=sr)
        Sx = Sx[:59]
        Sx = 10 * np.log10(Sx + 1e-10)

        # Resize to fixed size (59, 344) for CNN input
        Sx_resized = np.zeros((59, 344))
        width = min(Sx.shape[1], 344)
        Sx_resized[:, :width] = Sx[:, :width]

        spec_tensor = torch.tensor(Sx_resized, dtype=torch.float32).unsqueeze(0)
        label = self.label_map[row["name"]]
        return spec_tensor, label

full_dataset = BarkDataset(csv_path="updated_dataset.csv", audio_folder="segmented_barks")

train_size = int(0.33 * len(full_dataset))
val_size = int(0.33 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# # Modified version by Deborah, you'll find the orginial model after this section.

# %%
class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):
        super(CNN, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=16, kernel_size=3, padding="same")
        self.bn1 = nn.BatchNorm2d(16)

        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding="same")
        self.bn2 = nn.BatchNorm2d(32)

        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding="same")
        self.bn3 = nn.BatchNorm2d(64)

        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding="same")
        self.bn4 = nn.BatchNorm2d(128)

        self.dropout = nn.Dropout(p=0.5)

        # Dynamically calculate flattened size
        self.flattened_size = self.get_flattened_size((1, 1, 59, 344))
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def get_flattened_size(self, input_shape):
        with torch.no_grad():
            x = torch.zeros(input_shape)
            x = self.conv1(x)
            x = self.bn1(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv2(x)
            x = self.bn2(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv3(x)
            x = self.bn3(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv4(x)
            x = self.bn4(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            return x.numel()

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv4(x)
        x = self.bn4(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.dropout(x)
        x = torch.flatten(x, start_dim=1)
        x = self.linear(x)
        return F.softmax(x, dim=1)

# %%
def accuracy(y_hat, y):
    preds = torch.argmax(y_hat, dim=1)
    return (preds == y).float().mean()

# %%
from sklearn.utils.class_weight import compute_class_weight

DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
lr_values = [0.00045, 0.0004, 0.00035, 0.0003, 0.0002]
num_epochs = 20  # Increased epochs for deeper models
early_stopping_patience = 5
scheduler_step_size = 5
scheduler_gamma = 0.1

cnn_metrics = {}
cnn_models = {}

# Create weights to prioritize minority classes in the loss function
all_labels = []
for X_train, y_train in train_loader:
    all_labels.extend(y_train.cpu().numpy())  # Collect the labels from the data loader
all_labels = np.array(all_labels)
class_weights = compute_class_weight('balanced', classes=np.unique(all_labels), y=all_labels)
class_weights = torch.tensor(class_weights, dtype=torch.float).to(DEVICE)
loss_fn = nn.CrossEntropyLoss(weight=class_weights)

for lr in lr_values:
    cnn_metrics[lr] = {"accuracies": [], "losses": []}

    # Initialize the CNN with dynamic flattened size computation
    cnn = CNN(input_channels=1, num_classes=10).to(DEVICE)
    optimizer = optim.Adam(cnn.parameters(), lr=lr, weight_decay=1e-5)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step_size, gamma=scheduler_gamma)
    cnn_models[lr] = cnn

    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(num_epochs):
        cnn.train()  # Set model to training mode
        train_loss_sum = 0

        for iteration, (X_train, y_train) in enumerate(train_loader):
            X_train = X_train.to(DEVICE)
            y_train = y_train.to(DEVICE)

            optimizer.zero_grad()

            # Forward pass through the updated CNN
            y_hat = cnn(X_train)
            train_loss = loss_fn(y_hat, y_train)
            train_loss.backward()
            optimizer.step()

            train_loss_sum += train_loss.item()

        scheduler.step()  # Adjust learning rate

        cnn.eval()  # Set model to evaluation mode
        with torch.no_grad():
            val_accuracy_sum = 0
            val_loss_sum = 0

            for X_val, y_val in val_loader:
                X_val = X_val.to(DEVICE)
                y_val = y_val.to(DEVICE)

                # Forward pass during validation
                y_hat = cnn(X_val)

                val_accuracy_sum += (torch.argmax(y_hat, dim=1) == y_val).float().mean()
                val_loss_sum += loss_fn(y_hat, y_val)

            val_loss = (val_loss_sum / len(val_loader)).cpu()
            val_accuracy = (val_accuracy_sum / len(val_loader)).cpu()

            # Early stopping logic
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= early_stopping_patience:
                    print(f"Early stopping triggered for learning rate {lr}.")
                    break

            # Update metrics
            cnn_metrics[lr]["accuracies"].append(val_accuracy.item())
            cnn_metrics[lr]["losses"].append(val_loss.item())

        # Logging information
        print(f"LR = {lr} --- EPOCH = {epoch + 1}")
        print(f"Training loss = {train_loss_sum / len(train_loader):.4f}")
        print(f"Validation loss = {val_loss:.4f} --- Validation accuracy = {val_accuracy:.4f}")
# Out:
# LR = 0.00045 --- EPOCH = 1
# Training loss = 2.3082
# Validation loss = 2.2777 --- Validation accuracy = 0.2194
# LR = 0.00045 --- EPOCH = 2
# Training loss = 2.2499
# Validation loss = 2.2212 --- Validation accuracy = 0.3019
# LR = 0.00045 --- EPOCH = 3
# Training loss = 2.1638
# Validation loss = 2.1165 --- Validation accuracy = 0.4303
# LR = 0.00045 --- EPOCH = 4
# Training loss = 2.0802
# Validation loss = 2.0769 --- Validation accuracy = 0.4646
# LR = 0.00045 --- EPOCH = 5
# Training loss = 2.0262
# Validation loss = 2.0366 --- Validation accuracy = 0.5058
# LR = 0.00045 --- EPOCH = 6
# Training loss = 1.9676
# Validation loss = 1.9803 --- Validation accuracy = 0.5917
# LR = 0.00045 --- EPOCH = 7
# Training loss = 1.9305
# Validation loss = 1.9568 --- Validation accuracy = 0.6304
# LR = 0.00045 --- EPOCH = 8
# Training loss = 1.8971
# Validation loss = 1.9378 --- Validation accuracy = 0.6486
# LR = 0.00045 --- EPOCH = 9
# Training loss = 1.8785
# Validation loss = 1.9242 --- Validation accuracy = 0.6499
# LR = 0.00045 --- EPOCH = 10
# Training loss = 1.8648
# Validation loss = 1.9126 --- Validation accuracy = 0.6561
# LR = 0.00045 --- EPOCH = 11
# Training loss = 1.8453
# Validation loss = 1.9118 --- Validation accuracy = 0.6536
# LR = 0.00045 --- EPOCH = 12
# Training loss = 1.8477
# Validation loss = 1.9135 --- Validation accuracy = 0.6561
# LR = 0.00045 --- EPOCH = 13
# Training loss = 1.8595
# Validation loss = 1.9104 --- Validation accuracy = 0.6611
# LR = 0.00045 --- EPOCH = 14
# Training loss = 1.8462
# Validation loss = 1.9088 --- Validation accuracy = 0.6636
# LR = 0.00045 --- EPOCH = 15
# Training loss = 1.8450
# Validation loss = 1.9068 --- Validation accuracy = 0.6636
# LR = 0.00045 --- EPOCH = 16
# Training loss = 1.8336
# Validation loss = 1.9077 --- Validation accuracy = 0.6674
# LR = 0.00045 --- EPOCH = 17
# Training loss = 1.8355
# Validation loss = 1.9069 --- Validation accuracy = 0.6674
# LR = 0.00045 --- EPOCH = 18
# Training loss = 1.8490
# Validation loss = 1.9083 --- Validation accuracy = 0.6661
# LR = 0.00045 --- EPOCH = 19
# Training loss = 1.8462
# Validation loss = 1.9074 --- Validation accuracy = 0.6624
# Early stopping triggered for learning rate 0.00045.
# LR = 0.0004 --- EPOCH = 1
# Training loss = 2.3098
# Validation loss = 2.2845 --- Validation accuracy = 0.1933
# LR = 0.0004 --- EPOCH = 2
# Training loss = 2.2360
# Validation loss = 2.2278 --- Validation accuracy = 0.2571
# LR = 0.0004 --- EPOCH = 3
# Training loss = 2.1635
# Validation loss = 2.1760 --- Validation accuracy = 0.3283
# LR = 0.0004 --- EPOCH = 4
# Training loss = 2.1264
# Validation loss = 2.1474 --- Validation accuracy = 0.3083
# LR = 0.0004 --- EPOCH = 5
# Training loss = 2.0767
# Validation loss = 2.0806 --- Validation accuracy = 0.4333
# LR = 0.0004 --- EPOCH = 6
# Training loss = 2.0172
# Validation loss = 2.0624 --- Validation accuracy = 0.4478
# LR = 0.0004 --- EPOCH = 7
# Training loss = 1.9974
# Validation loss = 2.0489 --- Validation accuracy = 0.4810
# LR = 0.0004 --- EPOCH = 8
# Training loss = 1.9822
# Validation loss = 2.0366 --- Validation accuracy = 0.5022
# LR = 0.0004 --- EPOCH = 9
# Training loss = 1.9691
# Validation loss = 2.0223 --- Validation accuracy = 0.5110
# LR = 0.0004 --- EPOCH = 10
# Training loss = 1.9470
# Validation loss = 2.0045 --- Validation accuracy = 0.5178
# LR = 0.0004 --- EPOCH = 11
# Training loss = 1.9398
# Validation loss = 2.0019 --- Validation accuracy = 0.5235
# LR = 0.0004 --- EPOCH = 12
# Training loss = 1.9355
# Validation loss = 2.0002 --- Validation accuracy = 0.5310
# LR = 0.0004 --- EPOCH = 13
# Training loss = 1.9353
# Validation loss = 2.0001 --- Validation accuracy = 0.5335
# LR = 0.0004 --- EPOCH = 14
# Training loss = 1.9347
# Validation loss = 1.9978 --- Validation accuracy = 0.5310
# LR = 0.0004 --- EPOCH = 15
# Training loss = 1.9346
# Validation loss = 1.9990 --- Validation accuracy = 0.5322
# LR = 0.0004 --- EPOCH = 16
# Training loss = 1.9336
# Validation loss = 1.9991 --- Validation accuracy = 0.5322
# LR = 0.0004 --- EPOCH = 17
# Training loss = 1.9296
# Validation loss = 1.9972 --- Validation accuracy = 0.5360
# LR = 0.0004 --- EPOCH = 18
# Training loss = 1.9298
# Validation loss = 1.9970 --- Validation accuracy = 0.5360
# LR = 0.0004 --- EPOCH = 19
# Training loss = 1.9402
# Validation loss = 1.9970 --- Validation accuracy = 0.5372
# LR = 0.0004 --- EPOCH = 20
# Training loss = 1.9277
# Validation loss = 1.9969 --- Validation accuracy = 0.5347
# LR = 0.00035 --- EPOCH = 1
# Training loss = 2.2926
# Validation loss = 2.2856 --- Validation accuracy = 0.1451
# LR = 0.00035 --- EPOCH = 2
# Training loss = 2.2622
# Validation loss = 2.2494 --- Validation accuracy = 0.2014
# LR = 0.00035 --- EPOCH = 3
# Training loss = 2.2229
# Validation loss = 2.2387 --- Validation accuracy = 0.2101
# LR = 0.00035 --- EPOCH = 4
# Training loss = 2.2114
# Validation loss = 2.2299 --- Validation accuracy = 0.2214
# LR = 0.00035 --- EPOCH = 5
# Training loss = 2.1797
# Validation loss = 2.1931 --- Validation accuracy = 0.2776
# LR = 0.00035 --- EPOCH = 6
# Training loss = 2.1392
# Validation loss = 2.1637 --- Validation accuracy = 0.3258
# LR = 0.00035 --- EPOCH = 7
# Training loss = 2.1265
# Validation loss = 2.1564 --- Validation accuracy = 0.3433
# LR = 0.00035 --- EPOCH = 8
# Training loss = 2.1244
# Validation loss = 2.1505 --- Validation accuracy = 0.3533
# LR = 0.00035 --- EPOCH = 9
# Training loss = 2.1204
# Validation loss = 2.1443 --- Validation accuracy = 0.3558
# LR = 0.00035 --- EPOCH = 10
# Training loss = 2.1147
# Validation loss = 2.1385 --- Validation accuracy = 0.3708
# LR = 0.00035 --- EPOCH = 11
# Training loss = 2.0974
# Validation loss = 2.1387 --- Validation accuracy = 0.3696
# LR = 0.00035 --- EPOCH = 12
# Training loss = 2.1099
# Validation loss = 2.1359 --- Validation accuracy = 0.3658
# LR = 0.00035 --- EPOCH = 13
# Training loss = 2.0989
# Validation loss = 2.1385 --- Validation accuracy = 0.3721
# LR = 0.00035 --- EPOCH = 14
# Training loss = 2.1070
# Validation loss = 2.1359 --- Validation accuracy = 0.3708
# LR = 0.00035 --- EPOCH = 15
# Training loss = 2.0995
# Validation loss = 2.1357 --- Validation accuracy = 0.3708
# LR = 0.00035 --- EPOCH = 16
# Training loss = 2.0914
# Validation loss = 2.1359 --- Validation accuracy = 0.3733
# LR = 0.00035 --- EPOCH = 17
# Training loss = 2.0955
# Validation loss = 2.1351 --- Validation accuracy = 0.3733
# LR = 0.00035 --- EPOCH = 18
# Training loss = 2.1002
# Validation loss = 2.1351 --- Validation accuracy = 0.3733
# LR = 0.00035 --- EPOCH = 19
# Training loss = 2.0913
# Validation loss = 2.1349 --- Validation accuracy = 0.3758
# LR = 0.00035 --- EPOCH = 20
# Training loss = 2.1045
# Validation loss = 2.1359 --- Validation accuracy = 0.3733
# LR = 0.0003 --- EPOCH = 1
# Training loss = 2.3001
# Validation loss = 2.2825 --- Validation accuracy = 0.2119
# LR = 0.0003 --- EPOCH = 2
# Training loss = 2.2153
# Validation loss = 2.1894 --- Validation accuracy = 0.3465
# LR = 0.0003 --- EPOCH = 3
# Training loss = 2.1205
# Validation loss = 2.1477 --- Validation accuracy = 0.3990
# LR = 0.0003 --- EPOCH = 4
# Training loss = 2.0407
# Validation loss = 2.0640 --- Validation accuracy = 0.4815
# LR = 0.0003 --- EPOCH = 5
# Training loss = 1.9971
# Validation loss = 2.0156 --- Validation accuracy = 0.5435
# LR = 0.0003 --- EPOCH = 6
# Training loss = 1.9599
# Validation loss = 1.9868 --- Validation accuracy = 0.5599
# LR = 0.0003 --- EPOCH = 7
# Training loss = 1.9313
# Validation loss = 1.9810 --- Validation accuracy = 0.5761
# LR = 0.0003 --- EPOCH = 8
# Training loss = 1.9254
# Validation loss = 1.9746 --- Validation accuracy = 0.5699
# LR = 0.0003 --- EPOCH = 9
# Training loss = 1.9146
# Validation loss = 1.9699 --- Validation accuracy = 0.5799
# LR = 0.0003 --- EPOCH = 10
# Training loss = 1.9110
# Validation loss = 1.9699 --- Validation accuracy = 0.5774
# LR = 0.0003 --- EPOCH = 11
# Training loss = 1.9038
# Validation loss = 1.9698 --- Validation accuracy = 0.5811
# LR = 0.0003 --- EPOCH = 12
# Training loss = 1.8955
# Validation loss = 1.9689 --- Validation accuracy = 0.5799
# LR = 0.0003 --- EPOCH = 13
# Training loss = 1.9029
# Validation loss = 1.9689 --- Validation accuracy = 0.5786
# LR = 0.0003 --- EPOCH = 14
# Training loss = 1.9037
# Validation loss = 1.9669 --- Validation accuracy = 0.5761
# LR = 0.0003 --- EPOCH = 15
# Training loss = 1.9016
# Validation loss = 1.9684 --- Validation accuracy = 0.5824
# LR = 0.0003 --- EPOCH = 16
# Training loss = 1.9019
# Validation loss = 1.9671 --- Validation accuracy = 0.5824
# LR = 0.0003 --- EPOCH = 17
# Training loss = 1.8970
# Validation loss = 1.9689 --- Validation accuracy = 0.5811
# LR = 0.0003 --- EPOCH = 18
# Training loss = 1.8928
# Validation loss = 1.9694 --- Validation accuracy = 0.5811
# Early stopping triggered for learning rate 0.0003.
# LR = 0.0002 --- EPOCH = 1
# Training loss = 2.2991
# Validation loss = 2.2971 --- Validation accuracy = 0.2082
# LR = 0.0002 --- EPOCH = 2
# Training loss = 2.2319
# Validation loss = 2.2459 --- Validation accuracy = 0.2476
# LR = 0.0002 --- EPOCH = 3
# Training loss = 2.1725
# Validation loss = 2.1834 --- Validation accuracy = 0.3283
# LR = 0.0002 --- EPOCH = 4
# Training loss = 2.1286
# Validation loss = 2.1465 --- Validation accuracy = 0.3564
# LR = 0.0002 --- EPOCH = 5
# Training loss = 2.0756
# Validation loss = 2.0933 --- Validation accuracy = 0.4208
# LR = 0.0002 --- EPOCH = 6
# Training loss = 2.0190
# Validation loss = 2.0717 --- Validation accuracy = 0.4578
# LR = 0.0002 --- EPOCH = 7
# Training loss = 1.9948
# Validation loss = 2.0642 --- Validation accuracy = 0.4703
# LR = 0.0002 --- EPOCH = 8
# Training loss = 1.9846
# Validation loss = 2.0524 --- Validation accuracy = 0.4840
# LR = 0.0002 --- EPOCH = 9
# Training loss = 1.9747
# Validation loss = 2.0483 --- Validation accuracy = 0.4990
# LR = 0.0002 --- EPOCH = 10
# Training loss = 1.9616
# Validation loss = 2.0422 --- Validation accuracy = 0.5097
# LR = 0.0002 --- EPOCH = 11
# Training loss = 1.9683
# Validation loss = 2.0383 --- Validation accuracy = 0.5110
# LR = 0.0002 --- EPOCH = 12
# Training loss = 1.9671
# Validation loss = 2.0371 --- Validation accuracy = 0.5090
# LR = 0.0002 --- EPOCH = 13
# Training loss = 1.9659
# Validation loss = 2.0358 --- Validation accuracy = 0.5090
# LR = 0.0002 --- EPOCH = 14
# Training loss = 1.9590
# Validation loss = 2.0386 --- Validation accuracy = 0.5053
# LR = 0.0002 --- EPOCH = 15
# Training loss = 1.9606
# Validation loss = 2.0364 --- Validation accuracy = 0.5065
# LR = 0.0002 --- EPOCH = 16
# Training loss = 1.9620
# Validation loss = 2.0383 --- Validation accuracy = 0.5065
# LR = 0.0002 --- EPOCH = 17
# Training loss = 1.9589
# Validation loss = 2.0368 --- Validation accuracy = 0.5065
# Early stopping triggered for learning rate 0.0002.

# %%
#Changing plotting for new training
# Validation Accuracy Plot
for lr in lr_values:
    x_axis = list(range(len(cnn_metrics[lr]["accuracies"])))  # Dynamically calculate x-axis length
    plt.plot(x_axis, cnn_metrics[lr]["accuracies"], label=f"Validation accuracy (lr={lr})")

plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Iterations")
plt.legend()
plt.show()

# Validation Loss Plot
for lr in lr_values:
    x_axis = list(range(len(cnn_metrics[lr]["losses"])))  # Dynamically calculate x-axis length
    plt.plot(x_axis, cnn_metrics[lr]["losses"], label=f"Validation loss (lr={lr})")

plt.xlabel("Iteration")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Iterations")
plt.legend()
plt.show()


best_lr = min(lr_values, key=lambda lr: min(cnn_metrics[lr]["losses"]))  # Find best learning rate
best_cnn = cnn_models[best_lr]  # Get the best CNN model

# Evaluate on the test set
test_accuracy_sum = 0
for X_test, y_test in test_loader:
    X_test = X_test.to(DEVICE)
    y_test = y_test.to(DEVICE)
    y_hat = best_cnn(X_test)
    test_accuracy_sum += accuracy(y_hat, y_test)

test_accuracy = (test_accuracy_sum / len(test_loader)).cpu()
print(f"Test set accuracy of best CNN model (lr={best_lr}): {test_accuracy:.4f}")

# Display model complexity
total_params_cnn = sum(param.numel() for param in best_cnn.parameters())
print(f"Number of parameters in CNN: {total_params_cnn}")
# Out:
# Test set accuracy of best CNN model (lr=0.00045): 0.6671
# Number of parameters in CNN: 178282

# %% [markdown]
# # The following is the original model

# %%
#original CNN
class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):  # context has 3 classes
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=5, kernel_size=3, padding="same")
        self.conv2 = nn.Conv2d(in_channels=5, out_channels=10, kernel_size=3, padding="same")
        self.conv3 = nn.Conv2d(in_channels=10, out_channels=20, kernel_size=3, padding="same")

        # For spectrogram shape: (1, 59, 344) → after 3x maxpool2d(2), dims = (20, 7, 43)
        self.flattened_size = 20 * 7 * 43
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, start_dim=1)
        x = F.softmax(x, dim=1)
        x = self.linear(x)
        return x

# %%
#orginal training
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
lr_values = [0.01, 0.001, 0.0001]
num_epochs = 10
num_iterations_before_validation = 1000

cnn_metrics = {}
cnn_models = {}

loss_fn = nn.CrossEntropyLoss()

for lr in lr_values:
    cnn_metrics[lr] = {
        "accuracies": [],
        "losses": []
    }

    cnn = CNN().to(DEVICE)
    optimizer = optim.Adam(cnn.parameters(), lr)
    cnn_models[lr] = cnn

    for epoch in range(num_epochs):
        for iteration, (X_train, y_train) in enumerate(train_loader):
            X_train = X_train.to(DEVICE)
            y_train = y_train.to(DEVICE)
            optimizer.zero_grad()
            y_hat = cnn(X_train)
            train_loss = loss_fn(y_hat, y_train)
            train_loss.backward()
            optimizer.step()

            if iteration == len(train_loader) - 1:

                with torch.no_grad():
                    val_accuracy_sum = 0
                    val_loss_sum = 0
                    for X_val, y_val in val_loader:
                        X_val = X_val.to(DEVICE)
                        y_val = y_val.to(DEVICE)
                        y_hat = cnn(X_val)
                        val_accuracy_sum += accuracy(y_hat, y_val)
                        val_loss_sum += loss_fn(y_hat, y_val)
                    val_accuracy = (val_accuracy_sum / len(val_loader)).cpu()
                    val_loss = (val_loss_sum / len(val_loader)).cpu()
                    cnn_metrics[lr]["accuracies"].append(val_accuracy)
                    cnn_metrics[lr]["losses"].append(val_loss)
                    print(f"LR = {lr} --- EPOCH = {epoch} --- ITERATION = {iteration}")
                    print(f"Validation loss = {val_loss:.4f} --- Validation accuracy = {val_accuracy:.4f}")
# Out:
# LR = 0.01 --- EPOCH = 0 --- ITERATION = 24
# Validation loss = 1.0962 --- Validation accuracy = 0.3515
# LR = 0.01 --- EPOCH = 1 --- ITERATION = 24
# Validation loss = 1.0964 --- Validation accuracy = 0.3553
# LR = 0.01 --- EPOCH = 2 --- ITERATION = 24
# Validation loss = 1.0927 --- Validation accuracy = 0.3653
# LR = 0.01 --- EPOCH = 3 --- ITERATION = 24
# Validation loss = 1.0925 --- Validation accuracy = 0.3665
# LR = 0.01 --- EPOCH = 4 --- ITERATION = 24
# Validation loss = 1.0968 --- Validation accuracy = 0.3590
# LR = 0.01 --- EPOCH = 5 --- ITERATION = 24
# Validation loss = 1.0974 --- Validation accuracy = 0.3628
# LR = 0.01 --- EPOCH = 6 --- ITERATION = 24
# Validation loss = 1.0999 --- Validation accuracy = 0.3628
# LR = 0.01 --- EPOCH = 7 --- ITERATION = 24
# Validation loss = 1.0999 --- Validation accuracy = 0.3628
# LR = 0.01 --- EPOCH = 8 --- ITERATION = 24
# Validation loss = 1.1024 --- Validation accuracy = 0.3615
# LR = 0.01 --- EPOCH = 9 --- ITERATION = 24
# Validation loss = 1.1049 --- Validation accuracy = 0.3710
# LR = 0.001 --- EPOCH = 0 --- ITERATION = 24
# Validation loss = 1.0968 --- Validation accuracy = 0.3490
# LR = 0.001 --- EPOCH = 1 --- ITERATION = 24
# Validation loss = 1.0957 --- Validation accuracy = 0.3490
# LR = 0.001 --- EPOCH = 2 --- ITERATION = 24
# Validation loss = 1.0951 --- Validation accuracy = 0.3490
# LR = 0.001 --- EPOCH = 3 --- ITERATION = 24
# Validation loss = 1.0926 --- Validation accuracy = 0.3797
# LR = 0.001 --- EPOCH = 4 --- ITERATION = 24
# Validation loss = 1.0909 --- Validation accuracy = 0.3854
# LR = 0.001 --- EPOCH = 5 --- ITERATION = 24
# Validation loss = 1.0885 --- Validation accuracy = 0.4179
# LR = 0.001 --- EPOCH = 6 --- ITERATION = 24
# Validation loss = 1.0863 --- Validation accuracy = 0.4179
# LR = 0.001 --- EPOCH = 7 --- ITERATION = 24
# Validation loss = 1.0851 --- Validation accuracy = 0.4054
# LR = 0.001 --- EPOCH = 8 --- ITERATION = 24
# Validation loss = 1.0821 --- Validation accuracy = 0.4204
# LR = 0.001 --- EPOCH = 9 --- ITERATION = 24
# Validation loss = 1.0836 --- Validation accuracy = 0.4067
# LR = 0.0001 --- EPOCH = 0 --- ITERATION = 24
# Validation loss = 1.0980 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 1 --- ITERATION = 24
# Validation loss = 1.0978 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 2 --- ITERATION = 24
# Validation loss = 1.0977 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 3 --- ITERATION = 24
# Validation loss = 1.0975 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 4 --- ITERATION = 24
# Validation loss = 1.0973 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 5 --- ITERATION = 24
# Validation loss = 1.0971 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 6 --- ITERATION = 24
# Validation loss = 1.0968 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 7 --- ITERATION = 24
# Validation loss = 1.0966 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 8 --- ITERATION = 24
# Validation loss = 1.0964 --- Validation accuracy = 0.3490
# LR = 0.0001 --- EPOCH = 9 --- ITERATION = 24
# Validation loss = 1.0961 --- Validation accuracy = 0.3490

# %%
#original plotting plus lr 0.0001
x_axis = list(range(len(cnn_metrics[0.01]["accuracies"])))

plt.plot(x_axis, cnn_metrics[0.01]["accuracies"], label="Validation accuracy (lr=0.01)")
plt.plot(x_axis, cnn_metrics[0.001]["accuracies"], label="Validation accuracy (lr=0.001)")
plt.plot(x_axis, cnn_metrics[0.0001]["accuracies"], label="Validation accuracy (lr=0.0001)")
plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Iterations")
plt.legend()
plt.show()

plt.plot(x_axis, cnn_metrics[0.01]["losses"], label="Validation loss (lr=0.01)")
plt.plot(x_axis, cnn_metrics[0.001]["losses"], label="Validation loss (lr=0.001)")
plt.plot(x_axis, cnn_metrics[0.0001]["losses"], label="Validation loss (lr=0.0001)")
plt.xlabel("Iteration")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Iterations")
plt.legend()
plt.show()

test_accuracy_sum = 0
best_cnn = cnn_models[0.001]

for X_test, y_test in test_loader:
    X_test = X_test.to(DEVICE)
    y_test = y_test.to(DEVICE)
    y_hat = best_cnn(X_test)
    test_accuracy_sum += accuracy(y_hat, y_test)

test_accuracy = (test_accuracy_sum / len(test_loader)).cpu()
print(f"Test set accuracy of best CNN model: {test_accuracy:.4f}")

total_params_cnn = sum(param.numel() for param in best_cnn.parameters())
print(f"Number of parameters in CNN: {total_params_cnn}")
# Out:
# Test set accuracy of best CNN model: 0.4243
# Number of parameters in CNN: 20393

# %% [markdown]
# # Confusion Matrix

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.metrics import confusion_matrix

def evaluate_and_plot_confusion_matrix(model, test_loader, device, class_names):
    model.eval()
    all_preds = []
    all_labels = []

    with torch.no_grad():
        for inputs, labels in test_loader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)

            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())

    # Compute confusion matrix
    cm = confusion_matrix(all_labels, all_preds)

    # Plot confusion matrix
    plt.figure(figsize=(6, 5))
    sns.heatmap(cm, annot=True, fmt="d", cmap="Blues", xticklabels=class_names, yticklabels=class_names)
    plt.xlabel("Predicted Label")
    plt.ylabel("True Label")
    plt.title("Confusion Matrix")
    plt.show()

class_names = ["Farley", "Freid", "Keri", "Louie", "Luke", "Mac", "Roodie", "Rudy", "Siggy", "Zoe"]

best_lr = min(cnn_metrics, key=lambda lr: min(cnn_metrics[lr]["losses"]))  # Find best LR
best_model = cnn_models[best_lr]  # Get corresponding model

# Run confusion matrix evaluation
evaluate_and_plot_confusion_matrix(best_model, test_loader, DEVICE, class_names)

# %% [markdown]
# Save the best model

# %%
torch.save(best_cnn.state_dict(), "weightsForNamePredict.pth")
