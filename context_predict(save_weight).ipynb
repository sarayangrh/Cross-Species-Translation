# %% [markdown]
# <a href="https://colab.research.google.com/github/sarayangrh/MAIS202_Final_Project/blob/main/Model_based_on_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Downloading and Annotating Data

# %%
import librosa
import pandas as pd
import numpy as np
from IPython.lib.display import Audio
from matplotlib import pyplot as plt
import multiprocessing
import scipy.signal
from scipy import signal
import torch
import glob

# %%
! rm -r data
# Out:
# rm: cannot remove 'data': No such file or directory

# %% [markdown]
# Downloading the data

# %%
# !mkdir data
# !cd data && wget https://archive.org/download/dog-barks-raw/Dog%20Bark%20Data.zip
# !cd data && unzip -q "Dog Bark Data.zip"
# !ls data/"Dog Bark Data"/Dog
# Out:
# --2025-03-26 21:43:06--  https://archive.org/download/dog-barks-raw/Dog%20Bark%20Data.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://ia601806.us.archive.org/7/items/dog-barks-raw/Dog%20Bark%20Data.zip [following]
# --2025-03-26 21:43:10--  https://ia601806.us.archive.org/7/items/dog-barks-raw/Dog%20Bark%20Data.zip
# Resolving ia601806.us.archive.org (ia601806.us.archive.org)... 207.241.227.76
# Connecting to ia601806.us.archive.org (ia601806.us.archive.org)|207.241.227.76|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943878068 (1.8G) [application/zip]
# Saving to: ‘Dog Bark Data.zip’
#
# Dog Bark Data.zip   100%[===================>]   1.81G   111MB/s    in 20s
#
# 2025-03-26 21:43:31 (91.2 MB/s) - ‘Dog Bark Data.zip’ saved [1943878068/1943878068]

# %% [markdown]
# Annotating the data

# %%
paths = glob.glob('data/**/**/**/**/*.aif') + glob.glob('data/**/**/**/**/*.wav')

# %%
# This is the number of audiofiles
len(paths)
# Out:
# 720

# %%
# !mkdir data/audio

# %%
# Copied straight from the Earth Species github
import re
import shutil

filename = []
name = []
context = []

for path in paths:
    try:
        n, session, c, session_sequence, *_ = re.findall('(\w+)', path.split('/')[-1])
        if c not in ['A', 'C', 'P']:
            n, c, *_ = re.findall('(\w+)', path.split('/')[-1])
            if c not in ['A', 'C', 'P']:
                n, _, c = re.findall('(\w+)', path.split('/')[-1])
                c = c[0]
                if c not in ['A', 'C', 'P']: continue
    except:
        continue
    shutil.copy(path, 'data/audio')
    filename.append(path.split('/')[-1])
    name.append(n)
    context.append(c)

# %%
# Copied from Earth Species github
# This code parses the file names to extract the labels
fix_names = {
    'Freid3': 'Freid',
    'Freid4': 'Freid',
    'Fried': 'Freid',
    'Keri3': 'Keri',
    'Kerik': 'Keri',
    'Zzoe': 'Zoe',
    'luke': 'Luke',
    'Louis': 'Louie'

}

name = [n if n not in fix_names.keys() else fix_names[n] for n in name]

age_map = {
    'Farley': 3,
    'Freid': 5,
    'Keri': 4,
    'Louie': 2,
    'Luke': 5,
    'Mac': 5,
    'Roodie': 12,
    'Rudy': 11,
    'Siggy': 11,
    'Zoe': 7
}

weight_map = {
    'Farley': 25,
    'Freid': 6,
    'Keri': 34,
    'Louie': 19,
    'Luke': 25,
    'Mac': 34,
    'Roodie': 18,
    'Rudy': 32,
    'Siggy': 36,
    'Zoe': 16
}

sex_map = {
    'Farley': 'male',
    'Freid': 'male',
    'Keri': 'female',
    'Louie': 'male',
    'Luke': 'male',
    'Mac': 'male',
    'Roodie': 'male',
    'Rudy': 'male',
    'Siggy': 'male',
    'Zoe': 'female'
}

breed_map = {
    'Farley': 'Australian shepherd',
    'Freid': 'Dachsund',
    'Keri': 'Labrador mix',
    'Louie': 'Springer spaniel',
    'Luke': 'Australian shepherd',
    'Mac': 'German shorthair pointer',
    'Roodie': 'Australian cattle dog',
    'Rudy': 'German shorthair pointer',
    'Siggy': 'German shorthair pointer',
    'Zoe': 'Australian cattle dog'
}

age, weight, sex, breed = zip(*[(age_map[n], weight_map[n], sex_map[n], breed_map[n]) for n in name])

# %%
# Copied from Earth Species
# Creates a dataframe with all the different labels corresponding to each bark file
import pandas as pd

anno = pd.DataFrame(data={
    'filename': filename,
    'name': name,
    'context': context,
    'age': age,
    'weight': weight,
    'sex': sex,
    'breed': breed
})
context_map = {
    'A': 'aggression',
    'C': 'contact',
    'P': 'play'
}

anno.context = anno.context.apply(lambda c: context_map[c])

# %%
anno.head()
# Out:
#            filename   name  context  age  weight   sex  \
# 0  Siggy-4-P-4a.aif  Siggy     play   11      36  male
# 1  Siggy-4-C-4d.aif  Siggy  contact   11      36  male
# 2  Siggy-4-C-4c.aif  Siggy  contact   11      36  male
# 3  Siggy-4-C-4f.aif  Siggy  contact   11      36  male
# 4  Siggy-4-P-4c.aif  Siggy     play   11      36  male
#
#                       breed
# 0  German shorthair pointer
# 1  German shorthair pointer
# 2  German shorthair pointer
# 3  German shorthair pointer
# 4  German shorthair pointer

# %%
# Drop empty file
anno = anno[anno.filename != 'Siggy-4-A-4.aif']
# Create a csv file of the annotation
anno.to_csv('data/annotations.csv', index=False)

# %% [markdown]
# # 2. Generating Spectrograms

# %%
# !cd ..
anno = pd.read_csv('data/annotations.csv')

audio = []

for _, row in anno.iterrows():
    recording, sr = librosa.load(f'data/audio/{row.filename}', sr=None)
    audio.append(recording)

anno['audio'] = audio

# %%
anno.head()
# Out:
#            filename   name  context  age  weight   sex  \
# 0  Siggy-4-P-4a.aif  Siggy     play   11      36  male
# 1  Siggy-4-C-4d.aif  Siggy  contact   11      36  male
# 2  Siggy-4-C-4c.aif  Siggy  contact   11      36  male
# 3  Siggy-4-C-4f.aif  Siggy  contact   11      36  male
# 4  Siggy-4-P-4c.aif  Siggy     play   11      36  male
#
#                       breed                                              audio
# 0  German shorthair pointer  [0.07185364, 0.087509155, 0.09187317, 0.099029...
# 1  German shorthair pointer  [-0.00015258789, 0.00064086914, 0.0004272461, ...
# 2  German shorthair pointer  [0.0022583008, 0.0006866455, 0.0005187988, 0.0...
# 3  German shorthair pointer  [0.0019836426, 0.0011901855, 0.0004272461, 6.1...
# 4  German shorthair pointer  [0.00074768066, -0.00012207031, -0.00065612793...

# %%
sample_rate = 44100
def audio_to_spec(audio, sample_rate):
  # Compute spectrogram using SciPy
  freqs, times, Sx = signal.spectrogram(audio, fs=sample_rate)

  # Limit the frequency range to about 10kHz to limit computation
  freqs, Sx = freqs[:59], Sx[:59]

  # Convert to decibels (log-scale)
  epsilon = 1e-10  # Small constant to avoid log(0)
  Sx = 10 * np.log10(Sx + epsilon)

  return times, freqs, Sx

# %%
def plot_spectrogram(audio, sample_rate, title="Spectrogram"):
    times, freqs, Sx = audio_to_spec(audio, sample_rate)

    plt.figure(figsize=(10, 5))
    plt.pcolormesh(times, freqs / 1000, Sx, cmap='viridis')  # Convert to kHz
    plt.xlabel('Time [s]')
    plt.ylabel('Frequency [kHz]')
    plt.title(title)
    plt.colorbar(label='Power (dB)')
    plt.show()

# %%
# example
example_audio = anno["audio"][10]
plot_spectrogram(example_audio, sample_rate)

# %% [markdown]
# # 3. Segmenting Barks Using Clustering

# %% [markdown]
# Function to visualize the clustering

# %%
# Function to visualize bark segments
def visualize_bark_segments(audio_path, bark_groups, sample_rate, y):
    # Time axis
    time_axis = np.linspace(0, len(y) / sample_rate, num=len(y))

    plt.figure(figsize=(12, 5))
    librosa.display.waveshow(y, sr=sample_rate, alpha=0.5, color='gray', label="Waveform")

    # Highlight merged bark segments
    for start, end in bark_groups:
        plt.axvspan(start * (1), end * (1), color='red', alpha=0.3)  # Convert segment index to seconds

    plt.xlabel("Time (seconds)")
    plt.ylabel("Amplitude")
    plt.title(f"Bark Segmentation Visualization for {audio_path}")
    plt.legend(["Legend", "Waveform", "Bark (Red)"])
    plt.show()

# %% [markdown]
# Detecting barks using k-means clustering.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import soundfile as sf
import os

frame_length = 2048
hop_length = 512

# Since we want segments all of 1 second, segment length equals sampling rate
segment_length_s = 0.5
segment_length = int(sample_rate*segment_length_s)

# Make folder to store extracted barks
output_folder = "segmented_barks"
os.makedirs(output_folder, exist_ok=True)

all_labels = []
plotted = False
for file_idx, a in enumerate(audio):
  # Split audio into 1 second chunks
  segments = librosa.util.frame(a, frame_length=segment_length, hop_length=segment_length).T

  # Extract relevant features from each segment, in this case RMS
  features = []
  # store rms values for label correction
  rms_values = []
  for segment in segments:
    zcr = np.mean(librosa.feature.zero_crossing_rate(segment))  # Mean ZCR
    rms = np.mean(librosa.feature.rms(y=segment))  # Mean Energy
    centroid = np.mean(librosa.feature.spectral_centroid(y=segment, sr=sample_rate))  # Spectral Centroid
    mfcc = np.mean(librosa.feature.mfcc(y=segment, sr=sample_rate, n_mfcc=13), axis=1)  # MFCCs
    feature_vector = np.hstack([zcr, rms, centroid, mfcc])
    features.append(feature_vector)
    rms_values.append(rms)
  features = np.array(features)
  rms_values = np.array(rms_values)

  # Normalize
  scaler = StandardScaler()
  features_scaled = scaler.fit_transform(features)

  # K-Means
  kmeans = KMeans(n_clusters=2, random_state=42)
  labels = kmeans.fit_predict(features_scaled)

  # Label correction, 1 represents bark
  # This is done by assuming that a higher RMS => bark
  rms_per_cluster = [np.mean(rms_values[labels == cluster]) for cluster in np.unique(labels)]
  bark_cluster = np.argmax(rms_per_cluster)  # Identify high-energy cluster
  labels = np.array([1 if label == bark_cluster else 0 for label in labels])
  all_labels.append(labels)

  # Merge Consecutive Bark Segments -------------------
  # This is so barks can be variable in length
  bark_groups = []
  start_idx = None

  for i, label in enumerate(labels):
      if label == 1:
          if start_idx is None:
              start_idx = i  # Start of a new bark
      else:
          if start_idx is not None:
              bark_groups.append((start_idx, i))  # End previous bark
              start_idx = None
  if start_idx is not None:
      bark_groups.append((start_idx, len(labels)))

  # Extract and save the merged bark segments ----------
  for bark_id, (start, end) in enumerate(bark_groups):
        start_sample = start * segment_length
        end_sample = end * segment_length
        bark_audio = a[start_sample:end_sample]

        sf.write(f"{output_folder}/bark_{file_idx}_{bark_id}.wav", bark_audio, sample_rate)

  #--------------------------------------------------- Plot ------------------------------------------
  if not plotted:
    visualize_bark_segments(f"{output_folder}/bark_{file_idx}_{bark_id}.wav", bark_groups, segment_length, a)
    plotted = True

# %% [markdown]
# Now we have a folder called `segmented_barks` that contains all the segmented bark audio files. The files are named: "bark\_\<file-num\>\_\<seg-num\>" where \<file-num\> corresponds to each original recording and \<seg-num\> numbers each segment in each recording.

# %%
max_length = 0
bark_durations = [] # durations of barks in seconds

for file in os.listdir("segmented_barks"):
  a, sr = librosa.load(os.path.join("segmented_barks", file), sr=None)
  cur_length = len(a)
  bark_durations.append(cur_length / sample_rate)
  if cur_length > max_length:
    max_length = cur_length

print(f"The longest bark is {max_length / sample_rate:.2f} seconds.")
# Out:
# The longest bark is 22.00 seconds.

# %%
# Plot histogram
plt.figure(figsize=(10, 4))
plt.hist(bark_durations, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Bark Duration (seconds)")
plt.ylabel("Frequency")
plt.title("Distribution of Bark Durations")
plt.grid(True)
plt.show()

# %% [markdown]
# We can see that there are a very small amount of barks that are larger than 4 seconds. Let's remove these files.

# %%
target_duration = 4 # in seconds
target_length = target_duration * sample_rate

for file in os.listdir("segmented_barks"):
  file_path = os.path.join("segmented_barks", file)

  # Load the audio file
  y, sr = librosa.load(file_path, sr=None)
  duration = len(y) / sr  # Convert samples to seconds

  # Remove file if it exceeds max_duration
  if duration > target_duration:
    os.remove(file_path)
    # Uncomment to show which files are removed
    # print(f"Removed: {file} (Duration: {duration:.2f}s)")
  # Otherwise, pad the file to be 4 seconds
  elif duration < target_duration:
    padded_y = np.pad(y, (0, target_length - len(y)), mode='constant')
    sf.write(file_path, padded_y, sample_rate)
    # Uncomment to show which files are padded
    # print(f"Padded: {file} to 4 seconds")

# %% [markdown]
# Add segmented_barks to the old dataframe.

# %%
# Create a new DataFrame for segmented barks
bark_data = []

# Iterate over segmented bark files
for file in os.listdir("segmented_barks"):
  # Extract the file index from the filename (assuming format "bark_<file-num>_<seg-num>.wav")
  file_index = int(file.split("_")[1])

  # Find the original row using the file index
  # Recall the old dataframe is called anno
  row = anno.iloc[file_index].to_dict()

  # Update the "single_bark" column with the segmented file path
  row["single_bark"] = os.path.join("segmented_barks", file)

  # Append updated row to the new dataset
  bark_data.append(row)

# Create a new DataFrame with the segmented barks
df_barks = pd.DataFrame(bark_data)
df_barks = df_barks.drop(columns=["audio"])

df_barks.head()
# Out:
#             filename    name     context  age  weight     sex  \
# 0     Mac-2-P-2f.aif     Mac        play    5      34    male
# 1  Roodie-8-P-8b.aif  Roodie        play   12      18    male
# 2      Mac-4-A-4.aif     Mac  aggression    5      34    male
# 3    Mac-11-C-9a.aif     Mac     contact    5      34    male
# 4      Zoe-1-A-1.aif     Zoe  aggression    7      16  female
#
#                       breed                      single_bark
# 0  German shorthair pointer    segmented_barks/bark_79_1.wav
# 1     Australian cattle dog   segmented_barks/bark_285_3.wav
# 2  German shorthair pointer  segmented_barks/bark_110_14.wav
# 3  German shorthair pointer   segmented_barks/bark_120_0.wav
# 4     Australian cattle dog   segmented_barks/bark_225_0.wav

# %% [markdown]
# Data preprocessing is complete. The files that will be useful in training a model are `segmented_barks`, which is a folder containing all single bark audio files, and `updated_dataset.csv`, which is a csv with each segmented bark with its corresonding labels.

# %%
# Save the updated dataset
df_barks.to_csv("updated_dataset.csv", index=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset, random_split
import pandas as pd
import numpy as np
import os
from scipy import signal

class BarkDataset(Dataset):
    def __init__(self, csv_path, audio_folder, transform=None):
        self.data = pd.read_csv(csv_path)
        self.audio_folder = audio_folder
        self.transform = transform
        self.label_map = {"aggression": 0, "contact": 1, "play": 2}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        audio_path = os.path.join(self.audio_folder, os.path.basename(row["single_bark"]))
        y, sr = librosa.load(audio_path, sr=None)

        # Compute spectrogram
        freqs, times, Sx = signal.spectrogram(y, fs=sr)
        Sx = Sx[:59]
        Sx = 10 * np.log10(Sx + 1e-10)

        # Resize to fixed size (59, 344) for CNN input
        Sx_resized = np.zeros((59, 344))
        width = min(Sx.shape[1], 344)
        Sx_resized[:, :width] = Sx[:, :width]

        spec_tensor = torch.tensor(Sx_resized, dtype=torch.float32).unsqueeze(0)
        label = self.label_map[row["context"]]
        return spec_tensor, label

full_dataset = BarkDataset(csv_path="updated_dataset.csv", audio_folder="segmented_barks")

train_size = int(0.33 * len(full_dataset))
val_size = int(0.33 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# # Modified version by Deborah, you'll find the orginial model after this section.

# %%
#orginal CNN
'''
class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):  # context has 3 classes
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=5, kernel_size=3, padding="same")
        self.conv2 = nn.Conv2d(in_channels=5, out_channels=10, kernel_size=3, padding="same")
        self.conv3 = nn.Conv2d(in_channels=10, out_channels=20, kernel_size=3, padding="same")

        # For spectrogram shape: (1, 59, 344) → after 3x maxpool2d(2), dims = (20, 7, 43)
        self.flattened_size = 20 * 7 * 43
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, start_dim=1)
        x = F.softmax(x, dim=1)
        x = self.linear(x)
        return x
'''

class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):
        super(CNN, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=16, kernel_size=3, padding="same")
        self.bn1 = nn.BatchNorm2d(16)

        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding="same")
        self.bn2 = nn.BatchNorm2d(32)

        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding="same")
        self.bn3 = nn.BatchNorm2d(64)

        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding="same")
        self.bn4 = nn.BatchNorm2d(128)

        self.dropout = nn.Dropout(p=0.5)

        # Dynamically calculate flattened size
        self.flattened_size = self.get_flattened_size((1, 1, 59, 344))
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def get_flattened_size(self, input_shape):
        with torch.no_grad():
            x = torch.zeros(input_shape)
            x = self.conv1(x)
            x = self.bn1(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv2(x)
            x = self.bn2(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv3(x)
            x = self.bn3(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv4(x)
            x = self.bn4(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            return x.numel()

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv4(x)
        x = self.bn4(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.dropout(x)
        x = torch.flatten(x, start_dim=1)
        x = self.linear(x)
        return F.softmax(x, dim=1)

# %%
def accuracy(y_hat, y):
    preds = torch.argmax(y_hat, dim=1)
    return (preds == y).float().mean()

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
lr_values = [0.0005, 0.0004, 0.0003,0.0002,0.0001,]
num_epochs = 20  # Increased epochs for deeper models
early_stopping_patience = 5
scheduler_step_size = 8
scheduler_gamma = 0.1

cnn_metrics = {}
cnn_models = {}
loss_fn = nn.CrossEntropyLoss()

for lr in lr_values:
    cnn_metrics[lr] = {"accuracies": [], "losses": []}

    # Initialize the CNN with dynamic flattened size computation
    cnn = CNN(input_channels=1, num_classes=3).to(DEVICE)
    optimizer = optim.Adam(cnn.parameters(), lr=lr, weight_decay=1e-5)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step_size, gamma=scheduler_gamma)
    cnn_models[lr] = cnn

    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(num_epochs):
        cnn.train()  # Set model to training mode
        train_loss_sum = 0

        for iteration, (X_train, y_train) in enumerate(train_loader):
            X_train = X_train.to(DEVICE)
            y_train = y_train.to(DEVICE)

            optimizer.zero_grad()

            # Forward pass through the updated CNN
            y_hat = cnn(X_train)
            train_loss = loss_fn(y_hat, y_train)
            train_loss.backward()
            optimizer.step()

            train_loss_sum += train_loss.item()

        scheduler.step()  # Adjust learning rate

        cnn.eval()  # Set model to evaluation mode
        with torch.no_grad():
            val_accuracy_sum = 0
            val_loss_sum = 0

            for X_val, y_val in val_loader:
                X_val = X_val.to(DEVICE)
                y_val = y_val.to(DEVICE)

                # Forward pass during validation
                y_hat = cnn(X_val)

                val_accuracy_sum += (torch.argmax(y_hat, dim=1) == y_val).float().mean()
                val_loss_sum += loss_fn(y_hat, y_val)

            val_loss = (val_loss_sum / len(val_loader)).cpu()
            val_accuracy = (val_accuracy_sum / len(val_loader)).cpu()

            # Early stopping logic
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= early_stopping_patience:
                    print(f"Early stopping triggered for learning rate {lr}.")
                    break

            # Update metrices
            cnn_metrics[lr]["accuracies"].append(val_accuracy.item())
            cnn_metrics[lr]["losses"].append(val_loss.item())

        # Logging information
        print(f"LR = {lr} --- EPOCH = {epoch + 1}")
        print(f"Training loss = {train_loss_sum / len(train_loader):.4f}")
        print(f"Validation loss = {val_loss:.4f} --- Validation accuracy = {val_accuracy:.4f}")
# Out:
# LR = 0.0005 --- EPOCH = 1
# Training loss = 1.1014
# Validation loss = 1.1010 --- Validation accuracy = 0.3878
# LR = 0.0005 --- EPOCH = 2
# Training loss = 1.1087
# Validation loss = 1.0494 --- Validation accuracy = 0.4940
# LR = 0.0005 --- EPOCH = 3
# Training loss = 1.0810
# Validation loss = 1.0339 --- Validation accuracy = 0.5035
# LR = 0.0005 --- EPOCH = 4
# Training loss = 1.0599
# Validation loss = 1.0501 --- Validation accuracy = 0.4792
# LR = 0.0005 --- EPOCH = 5
# Training loss = 1.0400
# Validation loss = 1.0294 --- Validation accuracy = 0.5085
# LR = 0.0005 --- EPOCH = 6
# Training loss = 1.0414
# Validation loss = 1.0233 --- Validation accuracy = 0.5060
# LR = 0.0005 --- EPOCH = 7
# Training loss = 0.9803
# Validation loss = 1.0114 --- Validation accuracy = 0.5224
# LR = 0.0005 --- EPOCH = 8
# Training loss = 0.9264
# Validation loss = 1.0715 --- Validation accuracy = 0.4467
# LR = 0.0005 --- EPOCH = 9
# Training loss = 0.8952
# Validation loss = 0.8827 --- Validation accuracy = 0.6756
# LR = 0.0005 --- EPOCH = 10
# Training loss = 0.8716
# Validation loss = 0.8718 --- Validation accuracy = 0.6861
# LR = 0.0005 --- EPOCH = 11
# Training loss = 0.8720
# Validation loss = 0.8713 --- Validation accuracy = 0.6743
# LR = 0.0005 --- EPOCH = 12
# Training loss = 0.8572
# Validation loss = 0.8612 --- Validation accuracy = 0.6856
# LR = 0.0005 --- EPOCH = 13
# Training loss = 0.8427
# Validation loss = 0.8574 --- Validation accuracy = 0.6831
# LR = 0.0005 --- EPOCH = 14
# Training loss = 0.8406
# Validation loss = 0.8541 --- Validation accuracy = 0.7006
# LR = 0.0005 --- EPOCH = 15
# Training loss = 0.8354
# Validation loss = 0.8558 --- Validation accuracy = 0.6949
# LR = 0.0005 --- EPOCH = 16
# Training loss = 0.8326
# Validation loss = 0.8489 --- Validation accuracy = 0.6999
# LR = 0.0005 --- EPOCH = 17
# Training loss = 0.8229
# Validation loss = 0.8472 --- Validation accuracy = 0.7099
# LR = 0.0005 --- EPOCH = 18
# Training loss = 0.8194
# Validation loss = 0.8464 --- Validation accuracy = 0.7074
# LR = 0.0005 --- EPOCH = 19
# Training loss = 0.8175
# Validation loss = 0.8461 --- Validation accuracy = 0.7024
# LR = 0.0005 --- EPOCH = 20
# Training loss = 0.8229
# Validation loss = 0.8457 --- Validation accuracy = 0.7049
# LR = 0.0004 --- EPOCH = 1
# Training loss = 1.1017
# Validation loss = 1.0405 --- Validation accuracy = 0.4967
# LR = 0.0004 --- EPOCH = 2
# Training loss = 1.0430
# Validation loss = 1.0255 --- Validation accuracy = 0.4858
# LR = 0.0004 --- EPOCH = 3
# Training loss = 0.9646
# Validation loss = 1.0316 --- Validation accuracy = 0.4935
# LR = 0.0004 --- EPOCH = 4
# Training loss = 0.9547
# Validation loss = 1.0453 --- Validation accuracy = 0.4617
# LR = 0.0004 --- EPOCH = 5
# Training loss = 0.8969
# Validation loss = 0.9449 --- Validation accuracy = 0.5815
# LR = 0.0004 --- EPOCH = 6
# Training loss = 0.8793
# Validation loss = 1.0259 --- Validation accuracy = 0.4867
# LR = 0.0004 --- EPOCH = 7
# Training loss = 0.8959
# Validation loss = 0.9809 --- Validation accuracy = 0.5340
# LR = 0.0004 --- EPOCH = 8
# Training loss = 0.8545
# Validation loss = 0.9900 --- Validation accuracy = 0.5404
# LR = 0.0004 --- EPOCH = 9
# Training loss = 0.8046
# Validation loss = 0.8312 --- Validation accuracy = 0.7149
# LR = 0.0004 --- EPOCH = 10
# Training loss = 0.8067
# Validation loss = 0.8266 --- Validation accuracy = 0.7193
# LR = 0.0004 --- EPOCH = 11
# Training loss = 0.8045
# Validation loss = 0.8256 --- Validation accuracy = 0.7211
# LR = 0.0004 --- EPOCH = 12
# Training loss = 0.7873
# Validation loss = 0.8208 --- Validation accuracy = 0.7256
# LR = 0.0004 --- EPOCH = 13
# Training loss = 0.7802
# Validation loss = 0.8180 --- Validation accuracy = 0.7368
# LR = 0.0004 --- EPOCH = 14
# Training loss = 0.7691
# Validation loss = 0.8159 --- Validation accuracy = 0.7393
# LR = 0.0004 --- EPOCH = 15
# Training loss = 0.7773
# Validation loss = 0.8148 --- Validation accuracy = 0.7431
# LR = 0.0004 --- EPOCH = 16
# Training loss = 0.7607
# Validation loss = 0.8138 --- Validation accuracy = 0.7324
# LR = 0.0004 --- EPOCH = 17
# Training loss = 0.7676
# Validation loss = 0.8131 --- Validation accuracy = 0.7393
# LR = 0.0004 --- EPOCH = 18
# Training loss = 0.7738
# Validation loss = 0.8129 --- Validation accuracy = 0.7418
# LR = 0.0004 --- EPOCH = 19
# Training loss = 0.7607
# Validation loss = 0.8127 --- Validation accuracy = 0.7393
# LR = 0.0004 --- EPOCH = 20
# Training loss = 0.7630
# Validation loss = 0.8126 --- Validation accuracy = 0.7393
# LR = 0.0003 --- EPOCH = 1
# Training loss = 1.1133
# Validation loss = 1.0501 --- Validation accuracy = 0.4711
# LR = 0.0003 --- EPOCH = 2
# Training loss = 1.0348
# Validation loss = 1.0038 --- Validation accuracy = 0.5149
# LR = 0.0003 --- EPOCH = 3
# Training loss = 1.0002
# Validation loss = 0.9924 --- Validation accuracy = 0.5404
# LR = 0.0003 --- EPOCH = 4
# Training loss = 0.9560
# Validation loss = 0.9388 --- Validation accuracy = 0.5892
# LR = 0.0003 --- EPOCH = 5
# Training loss = 0.9197
# Validation loss = 0.9400 --- Validation accuracy = 0.5924
# LR = 0.0003 --- EPOCH = 6
# Training loss = 0.8810
# Validation loss = 0.9465 --- Validation accuracy = 0.5867
# LR = 0.0003 --- EPOCH = 7
# Training loss = 0.8714
# Validation loss = 0.8975 --- Validation accuracy = 0.6317
# LR = 0.0003 --- EPOCH = 8
# Training loss = 0.8558
# Validation loss = 0.8688 --- Validation accuracy = 0.6674
# LR = 0.0003 --- EPOCH = 9
# Training loss = 0.8005
# Validation loss = 0.8316 --- Validation accuracy = 0.7261
# LR = 0.0003 --- EPOCH = 10
# Training loss = 0.7951
# Validation loss = 0.8306 --- Validation accuracy = 0.7249
# LR = 0.0003 --- EPOCH = 11
# Training loss = 0.7903
# Validation loss = 0.8257 --- Validation accuracy = 0.7293
# LR = 0.0003 --- EPOCH = 12
# Training loss = 0.7932
# Validation loss = 0.8238 --- Validation accuracy = 0.7324
# LR = 0.0003 --- EPOCH = 13
# Training loss = 0.7890
# Validation loss = 0.8231 --- Validation accuracy = 0.7286
# LR = 0.0003 --- EPOCH = 14
# Training loss = 0.7767
# Validation loss = 0.8196 --- Validation accuracy = 0.7286
# LR = 0.0003 --- EPOCH = 15
# Training loss = 0.7652
# Validation loss = 0.8214 --- Validation accuracy = 0.7318
# LR = 0.0003 --- EPOCH = 16
# Training loss = 0.7670
# Validation loss = 0.8174 --- Validation accuracy = 0.7274
# LR = 0.0003 --- EPOCH = 17
# Training loss = 0.7681
# Validation loss = 0.8170 --- Validation accuracy = 0.7343
# LR = 0.0003 --- EPOCH = 18
# Training loss = 0.7658
# Validation loss = 0.8170 --- Validation accuracy = 0.7356
# LR = 0.0003 --- EPOCH = 19
# Training loss = 0.7600
# Validation loss = 0.8162 --- Validation accuracy = 0.7356
# LR = 0.0003 --- EPOCH = 20
# Training loss = 0.7631
# Validation loss = 0.8168 --- Validation accuracy = 0.7356
# LR = 0.0002 --- EPOCH = 1
# Training loss = 1.0906
# Validation loss = 1.1064 --- Validation accuracy = 0.3460
# LR = 0.0002 --- EPOCH = 2
# Training loss = 1.0264
# Validation loss = 0.9928 --- Validation accuracy = 0.5299
# LR = 0.0002 --- EPOCH = 3
# Training loss = 0.9912
# Validation loss = 0.9660 --- Validation accuracy = 0.5829
# LR = 0.0002 --- EPOCH = 4
# Training loss = 0.9658
# Validation loss = 0.9982 --- Validation accuracy = 0.5093
# LR = 0.0002 --- EPOCH = 5
# Training loss = 0.9372
# Validation loss = 0.9635 --- Validation accuracy = 0.5617
# LR = 0.0002 --- EPOCH = 6
# Training loss = 0.9132
# Validation loss = 0.9017 --- Validation accuracy = 0.6674
# LR = 0.0002 --- EPOCH = 7
# Training loss = 0.8789
# Validation loss = 0.8875 --- Validation accuracy = 0.6711
# LR = 0.0002 --- EPOCH = 8
# Training loss = 0.8783
# Validation loss = 0.9191 --- Validation accuracy = 0.6324
# LR = 0.0002 --- EPOCH = 9
# Training loss = 0.8481
# Validation loss = 0.8621 --- Validation accuracy = 0.7099
# LR = 0.0002 --- EPOCH = 10
# Training loss = 0.8174
# Validation loss = 0.8560 --- Validation accuracy = 0.7224
# LR = 0.0002 --- EPOCH = 11
# Training loss = 0.8121
# Validation loss = 0.8511 --- Validation accuracy = 0.7293
# LR = 0.0002 --- EPOCH = 12
# Training loss = 0.8079
# Validation loss = 0.8485 --- Validation accuracy = 0.7118
# LR = 0.0002 --- EPOCH = 13
# Training loss = 0.8100
# Validation loss = 0.8469 --- Validation accuracy = 0.7343
# LR = 0.0002 --- EPOCH = 14
# Training loss = 0.8008
# Validation loss = 0.8443 --- Validation accuracy = 0.7281
# LR = 0.0002 --- EPOCH = 15
# Training loss = 0.7948
# Validation loss = 0.8436 --- Validation accuracy = 0.7306
# LR = 0.0002 --- EPOCH = 16
# Training loss = 0.7912
# Validation loss = 0.8408 --- Validation accuracy = 0.7356
# LR = 0.0002 --- EPOCH = 17
# Training loss = 0.7887
# Validation loss = 0.8395 --- Validation accuracy = 0.7306
# LR = 0.0002 --- EPOCH = 18
# Training loss = 0.7890
# Validation loss = 0.8399 --- Validation accuracy = 0.7356
# LR = 0.0002 --- EPOCH = 19
# Training loss = 0.7943
# Validation loss = 0.8390 --- Validation accuracy = 0.7343
# LR = 0.0002 --- EPOCH = 20
# Training loss = 0.7957
# Validation loss = 0.8389 --- Validation accuracy = 0.7356
# LR = 0.0001 --- EPOCH = 1
# Training loss = 1.1080
# Validation loss = 1.0684 --- Validation accuracy = 0.4304
# LR = 0.0001 --- EPOCH = 2
# Training loss = 1.0386
# Validation loss = 1.0122 --- Validation accuracy = 0.5265
# LR = 0.0001 --- EPOCH = 3
# Training loss = 1.0045
# Validation loss = 0.9852 --- Validation accuracy = 0.5518
# LR = 0.0001 --- EPOCH = 4
# Training loss = 0.9795
# Validation loss = 0.9940 --- Validation accuracy = 0.5311
# LR = 0.0001 --- EPOCH = 5
# Training loss = 0.9636
# Validation loss = 0.9725 --- Validation accuracy = 0.5431
# LR = 0.0001 --- EPOCH = 6
# Training loss = 0.9459
# Validation loss = 0.9385 --- Validation accuracy = 0.6229
# LR = 0.0001 --- EPOCH = 7
# Training loss = 0.9184
# Validation loss = 0.9257 --- Validation accuracy = 0.6417
# LR = 0.0001 --- EPOCH = 8
# Training loss = 0.9030
# Validation loss = 0.9160 --- Validation accuracy = 0.6556
# LR = 0.0001 --- EPOCH = 9
# Training loss = 0.8907
# Validation loss = 0.9042 --- Validation accuracy = 0.6686
# LR = 0.0001 --- EPOCH = 10
# Training loss = 0.8800
# Validation loss = 0.9027 --- Validation accuracy = 0.6561
# LR = 0.0001 --- EPOCH = 11
# Training loss = 0.8696
# Validation loss = 0.8995 --- Validation accuracy = 0.6649
# LR = 0.0001 --- EPOCH = 12
# Training loss = 0.8709
# Validation loss = 0.8994 --- Validation accuracy = 0.6786
# LR = 0.0001 --- EPOCH = 13
# Training loss = 0.8628
# Validation loss = 0.8962 --- Validation accuracy = 0.6736
# LR = 0.0001 --- EPOCH = 14
# Training loss = 0.8585
# Validation loss = 0.8963 --- Validation accuracy = 0.6861
# LR = 0.0001 --- EPOCH = 15
# Training loss = 0.8708
# Validation loss = 0.8957 --- Validation accuracy = 0.6861
# LR = 0.0001 --- EPOCH = 16
# Training loss = 0.8769
# Validation loss = 0.8930 --- Validation accuracy = 0.6824
# LR = 0.0001 --- EPOCH = 17
# Training loss = 0.8651
# Validation loss = 0.8918 --- Validation accuracy = 0.6836
# LR = 0.0001 --- EPOCH = 18
# Training loss = 0.8551
# Validation loss = 0.8920 --- Validation accuracy = 0.6911
# LR = 0.0001 --- EPOCH = 19
# Training loss = 0.8621
# Validation loss = 0.8921 --- Validation accuracy = 0.6849
# LR = 0.0001 --- EPOCH = 20
# Training loss = 0.8607
# Validation loss = 0.8917 --- Validation accuracy = 0.6836

# %%
from google.colab import drive
drive.mount('/content/drive')

#Changing plotting for new training
# Validation Accuracy Plot
for lr in lr_values:
    x_axis = list(range(len(cnn_metrics[lr]["accuracies"])))  # Dynamically calculate x-axis length
    plt.plot(x_axis, cnn_metrics[lr]["accuracies"], label=f"Validation accuracy (lr={lr})")

plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Iterations")
plt.legend()
plt.show()

# Validation Loss Plot
for lr in lr_values:
    x_axis = list(range(len(cnn_metrics[lr]["losses"])))  # Dynamically calculate x-axis length
    plt.plot(x_axis, cnn_metrics[lr]["losses"], label=f"Validation loss (lr={lr})")

plt.xlabel("Iteration")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Iterations")
plt.legend()
plt.show()


best_lr = min(lr_values, key=lambda lr: min(cnn_metrics[lr]["losses"]))
best_cnn = cnn_models[best_lr]  # Get the best CNN model

torch.save(best_cnn.state_dict(), "/content/drive/MyDrive/MAIS Team /final_best_cnn_weights.pth")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
# Evaluate on the test set
model = CNN(input_channels=1, num_classes=3).to(DEVICE)
model.load_state_dict(torch.load("/content/drive/MyDrive/MAIS Team /final_best_cnn_weights.pth"))
model.eval()

test_accuracy_sum = 0
for X_test, y_test in test_loader:
    X_test = X_test.to(DEVICE)
    y_test = y_test.to(DEVICE)
    y_hat = best_cnn(X_test)
    test_accuracy_sum += accuracy(y_hat, y_test)

test_accuracy = (test_accuracy_sum / len(test_loader)).cpu()
print(f"Test set accuracy of best CNN model (lr={best_lr}): {test_accuracy:.4f}")

# Display model complexity
total_params_cnn = sum(param.numel() for param in best_cnn.parameters())
print(f"Number of parameters in CNN: {total_params_cnn}")
# Out:
# Test set accuracy of best CNN model (lr=0.0004): 0.7151
# Number of parameters in CNN: 121827
