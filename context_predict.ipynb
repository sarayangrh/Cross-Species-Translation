# %% [markdown]
# <a href="https://colab.research.google.com/github/sarayangrh/MAIS202_Final_Project/blob/main/Model_based_on_data.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #1. Downloading and Annotating Data

# %%
import librosa
import pandas as pd
import numpy as np
from IPython.lib.display import Audio
from matplotlib import pyplot as plt
import multiprocessing
import scipy.signal
from scipy import signal
import torch
import glob

# %%
! rm -r data
# Out:
# rm: cannot remove 'data': No such file or directory

# %% [markdown]
# Downloading the data

# %%
# !mkdir data
# !cd data && wget https://archive.org/download/dog-barks-raw/Dog%20Bark%20Data.zip
# !cd data && unzip -q "Dog Bark Data.zip"
# !ls data/"Dog Bark Data"/Dog
# Out:
# --2025-03-26 04:35:13--  https://archive.org/download/dog-barks-raw/Dog%20Bark%20Data.zip
# Resolving archive.org (archive.org)... 207.241.224.2
# Connecting to archive.org (archive.org)|207.241.224.2|:443... connected.
# HTTP request sent, awaiting response... 302 Found
# Location: https://dn790000.ca.archive.org/0/items/dog-barks-raw/Dog%20Bark%20Data.zip [following]
# --2025-03-26 04:35:14--  https://dn790000.ca.archive.org/0/items/dog-barks-raw/Dog%20Bark%20Data.zip
# Resolving dn790000.ca.archive.org (dn790000.ca.archive.org)... 184.105.203.167
# Connecting to dn790000.ca.archive.org (dn790000.ca.archive.org)|184.105.203.167|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 1943878068 (1.8G) [application/zip]
# Saving to: ‘Dog Bark Data.zip’
#
# Dog Bark Data.zip   100%[===================>]   1.81G  39.4MB/s    in 38s
#
# 2025-03-26 04:35:53 (48.5 MB/s) - ‘Dog Bark Data.zip’ saved [1943878068/1943878068]

# %% [markdown]
# Annotating the data

# %%
paths = glob.glob('data/**/**/**/**/*.aif') + glob.glob('data/**/**/**/**/*.wav')

# %%
# This is the number of audiofiles
len(paths)
# Out:
# 720

# %%
# !mkdir data/audio

# %%
# Copied straight from the Earth Species github
import re
import shutil

filename = []
name = []
context = []

for path in paths:
    try:
        n, session, c, session_sequence, *_ = re.findall('(\w+)', path.split('/')[-1])
        if c not in ['A', 'C', 'P']:
            n, c, *_ = re.findall('(\w+)', path.split('/')[-1])
            if c not in ['A', 'C', 'P']:
                n, _, c = re.findall('(\w+)', path.split('/')[-1])
                c = c[0]
                if c not in ['A', 'C', 'P']: continue
    except:
        continue
    shutil.copy(path, 'data/audio')
    filename.append(path.split('/')[-1])
    name.append(n)
    context.append(c)

# %%
# Copied from Earth Species github
# This code parses the file names to extract the labels
fix_names = {
    'Freid3': 'Freid',
    'Freid4': 'Freid',
    'Fried': 'Freid',
    'Keri3': 'Keri',
    'Kerik': 'Keri',
    'Zzoe': 'Zoe',
    'luke': 'Luke',
    'Louis': 'Louie'

}

name = [n if n not in fix_names.keys() else fix_names[n] for n in name]

age_map = {
    'Farley': 3,
    'Freid': 5,
    'Keri': 4,
    'Louie': 2,
    'Luke': 5,
    'Mac': 5,
    'Roodie': 12,
    'Rudy': 11,
    'Siggy': 11,
    'Zoe': 7
}

weight_map = {
    'Farley': 25,
    'Freid': 6,
    'Keri': 34,
    'Louie': 19,
    'Luke': 25,
    'Mac': 34,
    'Roodie': 18,
    'Rudy': 32,
    'Siggy': 36,
    'Zoe': 16
}

sex_map = {
    'Farley': 'male',
    'Freid': 'male',
    'Keri': 'female',
    'Louie': 'male',
    'Luke': 'male',
    'Mac': 'male',
    'Roodie': 'male',
    'Rudy': 'male',
    'Siggy': 'male',
    'Zoe': 'female'
}

breed_map = {
    'Farley': 'Australian shepherd',
    'Freid': 'Dachsund',
    'Keri': 'Labrador mix',
    'Louie': 'Springer spaniel',
    'Luke': 'Australian shepherd',
    'Mac': 'German shorthair pointer',
    'Roodie': 'Australian cattle dog',
    'Rudy': 'German shorthair pointer',
    'Siggy': 'German shorthair pointer',
    'Zoe': 'Australian cattle dog'
}

age, weight, sex, breed = zip(*[(age_map[n], weight_map[n], sex_map[n], breed_map[n]) for n in name])

# %%
# Copied from Earth Species
# Creates a dataframe with all the different labels corresponding to each bark file
import pandas as pd

anno = pd.DataFrame(data={
    'filename': filename,
    'name': name,
    'context': context,
    'age': age,
    'weight': weight,
    'sex': sex,
    'breed': breed
})
context_map = {
    'A': 'aggression',
    'C': 'contact',
    'P': 'play'
}

anno.context = anno.context.apply(lambda c: context_map[c])

# %%
anno.head()
# Out:
#            filename   name  context  age  weight   sex  \
# 0  Siggy-4-P-4a.aif  Siggy     play   11      36  male
# 1  Siggy-4-C-4d.aif  Siggy  contact   11      36  male
# 2  Siggy-4-C-4c.aif  Siggy  contact   11      36  male
# 3  Siggy-4-C-4f.aif  Siggy  contact   11      36  male
# 4  Siggy-4-P-4c.aif  Siggy     play   11      36  male
#
#                       breed
# 0  German shorthair pointer
# 1  German shorthair pointer
# 2  German shorthair pointer
# 3  German shorthair pointer
# 4  German shorthair pointer

# %%
# Drop empty file
anno = anno[anno.filename != 'Siggy-4-A-4.aif']
# Create a csv file of the annotation
anno.to_csv('data/annotations.csv', index=False)

# %% [markdown]
# # 2. Generating Spectrograms

# %%
# !cd ..
anno = pd.read_csv('data/annotations.csv')

audio = []

for _, row in anno.iterrows():
    recording, sr = librosa.load(f'data/audio/{row.filename}', sr=None)
    audio.append(recording)

anno['audio'] = audio

# %%
anno.head()
# Out:
#            filename   name  context  age  weight   sex  \
# 0  Siggy-4-P-4a.aif  Siggy     play   11      36  male
# 1  Siggy-4-C-4d.aif  Siggy  contact   11      36  male
# 2  Siggy-4-C-4c.aif  Siggy  contact   11      36  male
# 3  Siggy-4-C-4f.aif  Siggy  contact   11      36  male
# 4  Siggy-4-P-4c.aif  Siggy     play   11      36  male
#
#                       breed                                              audio
# 0  German shorthair pointer  [0.07185364, 0.087509155, 0.09187317, 0.099029...
# 1  German shorthair pointer  [-0.00015258789, 0.00064086914, 0.0004272461, ...
# 2  German shorthair pointer  [0.0022583008, 0.0006866455, 0.0005187988, 0.0...
# 3  German shorthair pointer  [0.0019836426, 0.0011901855, 0.0004272461, 6.1...
# 4  German shorthair pointer  [0.00074768066, -0.00012207031, -0.00065612793...

# %%
sample_rate = 44100
def audio_to_spec(audio, sample_rate):
  # Compute spectrogram using SciPy
  freqs, times, Sx = signal.spectrogram(audio, fs=sample_rate)

  # Limit the frequency range to about 10kHz to limit computation
  freqs, Sx = freqs[:59], Sx[:59]

  # Convert to decibels (log-scale)
  epsilon = 1e-10  # Small constant to avoid log(0)
  Sx = 10 * np.log10(Sx + epsilon)

  return times, freqs, Sx

# %%
def plot_spectrogram(audio, sample_rate, title="Spectrogram"):
    times, freqs, Sx = audio_to_spec(audio, sample_rate)

    plt.figure(figsize=(10, 5))
    plt.pcolormesh(times, freqs / 1000, Sx, cmap='viridis')  # Convert to kHz
    plt.xlabel('Time [s]')
    plt.ylabel('Frequency [kHz]')
    plt.title(title)
    plt.colorbar(label='Power (dB)')
    plt.show()

# %%
# example
example_audio = anno["audio"][10]
plot_spectrogram(example_audio, sample_rate)

# %% [markdown]
# # 3. Segmenting Barks Using Clustering

# %% [markdown]
# Function to visualize the clustering

# %%
# Function to visualize bark segments
def visualize_bark_segments(audio_path, bark_groups, sample_rate, y):
    # Time axis
    time_axis = np.linspace(0, len(y) / sample_rate, num=len(y))

    plt.figure(figsize=(12, 5))
    librosa.display.waveshow(y, sr=sample_rate, alpha=0.5, color='gray', label="Waveform")

    # Highlight merged bark segments
    for start, end in bark_groups:
        plt.axvspan(start * (1), end * (1), color='red', alpha=0.3)  # Convert segment index to seconds

    plt.xlabel("Time (seconds)")
    plt.ylabel("Amplitude")
    plt.title(f"Bark Segmentation Visualization for {audio_path}")
    plt.legend(["Legend", "Waveform", "Bark (Red)"])
    plt.show()

# %% [markdown]
# Detecting barks using k-means clustering.

# %%
from sklearn.preprocessing import StandardScaler
from sklearn.cluster import KMeans
import soundfile as sf
import os

frame_length = 2048
hop_length = 512

# Since we want segments all of 1 second, segment length equals sampling rate
segment_length_s = 0.5
segment_length = int(sample_rate*segment_length_s)

# Make folder to store extracted barks
output_folder = "segmented_barks"
os.makedirs(output_folder, exist_ok=True)

all_labels = []
plotted = False
for file_idx, a in enumerate(audio):
  # Split audio into 1 second chunks
  segments = librosa.util.frame(a, frame_length=segment_length, hop_length=segment_length).T

  # Extract relevant features from each segment, in this case RMS
  features = []
  # store rms values for label correction
  rms_values = []
  for segment in segments:
    zcr = np.mean(librosa.feature.zero_crossing_rate(segment))  # Mean ZCR
    rms = np.mean(librosa.feature.rms(y=segment))  # Mean Energy
    centroid = np.mean(librosa.feature.spectral_centroid(y=segment, sr=sample_rate))  # Spectral Centroid
    mfcc = np.mean(librosa.feature.mfcc(y=segment, sr=sample_rate, n_mfcc=13), axis=1)  # MFCCs
    feature_vector = np.hstack([zcr, rms, centroid, mfcc])
    features.append(feature_vector)
    rms_values.append(rms)
  features = np.array(features)
  rms_values = np.array(rms_values)

  # Normalize
  scaler = StandardScaler()
  features_scaled = scaler.fit_transform(features)

  # K-Means
  kmeans = KMeans(n_clusters=2, random_state=42)
  labels = kmeans.fit_predict(features_scaled)

  # Label correction, 1 represents bark
  # This is done by assuming that a higher RMS => bark
  rms_per_cluster = [np.mean(rms_values[labels == cluster]) for cluster in np.unique(labels)]
  bark_cluster = np.argmax(rms_per_cluster)  # Identify high-energy cluster
  labels = np.array([1 if label == bark_cluster else 0 for label in labels])
  all_labels.append(labels)

  # Merge Consecutive Bark Segments -------------------
  # This is so barks can be variable in length
  bark_groups = []
  start_idx = None

  for i, label in enumerate(labels):
      if label == 1:
          if start_idx is None:
              start_idx = i  # Start of a new bark
      else:
          if start_idx is not None:
              bark_groups.append((start_idx, i))  # End previous bark
              start_idx = None
  if start_idx is not None:
      bark_groups.append((start_idx, len(labels)))

  # Extract and save the merged bark segments ----------
  for bark_id, (start, end) in enumerate(bark_groups):
        start_sample = start * segment_length
        end_sample = end * segment_length
        bark_audio = a[start_sample:end_sample]

        sf.write(f"{output_folder}/bark_{file_idx}_{bark_id}.wav", bark_audio, sample_rate)

  #--------------------------------------------------- Plot ------------------------------------------
  if not plotted:
    visualize_bark_segments(f"{output_folder}/bark_{file_idx}_{bark_id}.wav", bark_groups, segment_length, a)
    plotted = True

# %% [markdown]
# Now we have a folder called `segmented_barks` that contains all the segmented bark audio files. The files are named: "bark\_\<file-num\>\_\<seg-num\>" where \<file-num\> corresponds to each original recording and \<seg-num\> numbers each segment in each recording.

# %%
max_length = 0
bark_durations = [] # durations of barks in seconds

for file in os.listdir("segmented_barks"):
  a, sr = librosa.load(os.path.join("segmented_barks", file), sr=None)
  cur_length = len(a)
  bark_durations.append(cur_length / sample_rate)
  if cur_length > max_length:
    max_length = cur_length

print(f"The longest bark is {max_length / sample_rate:.2f} seconds.")
# Out:
# The longest bark is 22.00 seconds.

# %%
# Plot histogram
plt.figure(figsize=(10, 4))
plt.hist(bark_durations, bins=20, color='blue', alpha=0.7, edgecolor='black')
plt.xlabel("Bark Duration (seconds)")
plt.ylabel("Frequency")
plt.title("Distribution of Bark Durations")
plt.grid(True)
plt.show()

# %% [markdown]
# We can see that there are a very small amount of barks that are larger than 4 seconds. Let's remove these files.

# %%
target_duration = 4 # in seconds
target_length = target_duration * sample_rate

for file in os.listdir("segmented_barks"):
  file_path = os.path.join("segmented_barks", file)

  # Load the audio file
  y, sr = librosa.load(file_path, sr=None)
  duration = len(y) / sr  # Convert samples to seconds

  # Remove file if it exceeds max_duration
  if duration > target_duration:
    os.remove(file_path)
    # Uncomment to show which files are removed
    # print(f"Removed: {file} (Duration: {duration:.2f}s)")
  # Otherwise, pad the file to be 4 seconds
  elif duration < target_duration:
    padded_y = np.pad(y, (0, target_length - len(y)), mode='constant')
    sf.write(file_path, padded_y, sample_rate)
    # Uncomment to show which files are padded
    # print(f"Padded: {file} to 4 seconds")

# %% [markdown]
# Add segmented_barks to the old dataframe.

# %%
# Create a new DataFrame for segmented barks
bark_data = []

# Iterate over segmented bark files
for file in os.listdir("segmented_barks"):
  # Extract the file index from the filename (assuming format "bark_<file-num>_<seg-num>.wav")
  file_index = int(file.split("_")[1])

  # Find the original row using the file index
  # Recall the old dataframe is called anno
  row = anno.iloc[file_index].to_dict()

  # Update the "single_bark" column with the segmented file path
  row["single_bark"] = os.path.join("segmented_barks", file)

  # Append updated row to the new dataset
  bark_data.append(row)

# Create a new DataFrame with the segmented barks
df_barks = pd.DataFrame(bark_data)
df_barks = df_barks.drop(columns=["audio"])

df_barks.head()
# Out:
#             filename    name     context  age  weight     sex  \
# 0     Mac-2-P-2f.aif     Mac        play    5      34    male
# 1  Roodie-8-P-8b.aif  Roodie        play   12      18    male
# 2      Mac-4-A-4.aif     Mac  aggression    5      34    male
# 3    Mac-11-C-9a.aif     Mac     contact    5      34    male
# 4      Zoe-1-A-1.aif     Zoe  aggression    7      16  female
#
#                       breed                      single_bark
# 0  German shorthair pointer    segmented_barks/bark_79_1.wav
# 1     Australian cattle dog   segmented_barks/bark_285_3.wav
# 2  German shorthair pointer  segmented_barks/bark_110_14.wav
# 3  German shorthair pointer   segmented_barks/bark_120_0.wav
# 4     Australian cattle dog   segmented_barks/bark_225_0.wav

# %% [markdown]
# Data preprocessing is complete. The files that will be useful in training a model are `segmented_barks`, which is a folder containing all single bark audio files, and `updated_dataset.csv`, which is a csv with each segmented bark with its corresonding labels.

# %%
# Save the updated dataset
df_barks.to_csv("updated_dataset.csv", index=False)

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.optim as optim
import matplotlib.pyplot as plt
from tqdm import tqdm
from torch.utils.data import DataLoader, Dataset, random_split
import pandas as pd
import numpy as np
import os
from scipy import signal

class BarkDataset(Dataset):
    def __init__(self, csv_path, audio_folder, transform=None):
        self.data = pd.read_csv(csv_path)
        self.audio_folder = audio_folder
        self.transform = transform
        self.label_map = {"aggression": 0, "contact": 1, "play": 2}

    def __len__(self):
        return len(self.data)

    def __getitem__(self, idx):
        row = self.data.iloc[idx]
        audio_path = os.path.join(self.audio_folder, os.path.basename(row["single_bark"]))
        y, sr = librosa.load(audio_path, sr=None)

        # Compute spectrogram
        freqs, times, Sx = signal.spectrogram(y, fs=sr)
        Sx = Sx[:59]
        Sx = 10 * np.log10(Sx + 1e-10)

        # Resize to fixed size (59, 344) for CNN input
        Sx_resized = np.zeros((59, 344))
        width = min(Sx.shape[1], 344)
        Sx_resized[:, :width] = Sx[:, :width]

        spec_tensor = torch.tensor(Sx_resized, dtype=torch.float32).unsqueeze(0)
        label = self.label_map[row["context"]]
        return spec_tensor, label

full_dataset = BarkDataset(csv_path="updated_dataset.csv", audio_folder="segmented_barks")

train_size = int(0.33 * len(full_dataset))
val_size = int(0.33 * len(full_dataset))
test_size = len(full_dataset) - train_size - val_size

train_dataset, val_dataset, test_dataset = random_split(full_dataset, [train_size, val_size, test_size])

batch_size = 32
train_loader = DataLoader(train_dataset, batch_size=batch_size, shuffle=True)
val_loader = DataLoader(val_dataset, batch_size=batch_size)
test_loader = DataLoader(test_dataset, batch_size=batch_size)

# %% [markdown]
# # Modified version by Deborah, you'll find the orginial model after this section.

# %%
#orginal CNN
'''
class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):  # context has 3 classes
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=5, kernel_size=3, padding="same")
        self.conv2 = nn.Conv2d(in_channels=5, out_channels=10, kernel_size=3, padding="same")
        self.conv3 = nn.Conv2d(in_channels=10, out_channels=20, kernel_size=3, padding="same")

        # For spectrogram shape: (1, 59, 344) → after 3x maxpool2d(2), dims = (20, 7, 43)
        self.flattened_size = 20 * 7 * 43
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, start_dim=1)
        x = F.softmax(x, dim=1)
        x = self.linear(x)
        return x
'''

class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):
        super(CNN, self).__init__()

        # Convolutional layers
        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=16, kernel_size=3, padding="same")
        self.bn1 = nn.BatchNorm2d(16)

        self.conv2 = nn.Conv2d(in_channels=16, out_channels=32, kernel_size=3, padding="same")
        self.bn2 = nn.BatchNorm2d(32)

        self.conv3 = nn.Conv2d(in_channels=32, out_channels=64, kernel_size=3, padding="same")
        self.bn3 = nn.BatchNorm2d(64)

        self.conv4 = nn.Conv2d(in_channels=64, out_channels=128, kernel_size=3, padding="same")
        self.bn4 = nn.BatchNorm2d(128)

        self.dropout = nn.Dropout(p=0.5)

        # Dynamically calculate flattened size
        self.flattened_size = self.get_flattened_size((1, 1, 59, 344))
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def get_flattened_size(self, input_shape):
        with torch.no_grad():
            x = torch.zeros(input_shape)
            x = self.conv1(x)
            x = self.bn1(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv2(x)
            x = self.bn2(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv3(x)
            x = self.bn3(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            x = self.conv4(x)
            x = self.bn4(x)
            x = F.relu(x)
            x = F.max_pool2d(x, 2)

            return x.numel()

    def forward(self, x):
        x = self.conv1(x)
        x = self.bn1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = self.bn2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = self.bn3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv4(x)
        x = self.bn4(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.dropout(x)
        x = torch.flatten(x, start_dim=1)
        x = self.linear(x)
        return F.softmax(x, dim=1)

# %%
def accuracy(y_hat, y):
    preds = torch.argmax(y_hat, dim=1)
    return (preds == y).float().mean()

# %%
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
lr_values = [0.0005, 0.0004, 0.0003,0.0002,0.0001,]
num_epochs = 20  # Increased epochs for deeper models
early_stopping_patience = 5
scheduler_step_size = 8
scheduler_gamma = 0.1

cnn_metrics = {}
cnn_models = {}
loss_fn = nn.CrossEntropyLoss()

for lr in lr_values:
    cnn_metrics[lr] = {"accuracies": [], "losses": []}

    # Initialize the CNN with dynamic flattened size computation
    cnn = CNN(input_channels=1, num_classes=3).to(DEVICE)
    optimizer = optim.Adam(cnn.parameters(), lr=lr, weight_decay=1e-5)
    scheduler = optim.lr_scheduler.StepLR(optimizer, step_size=scheduler_step_size, gamma=scheduler_gamma)
    cnn_models[lr] = cnn

    best_val_loss = float('inf')
    patience_counter = 0

    for epoch in range(num_epochs):
        cnn.train()  # Set model to training mode
        train_loss_sum = 0

        for iteration, (X_train, y_train) in enumerate(train_loader):
            X_train = X_train.to(DEVICE)
            y_train = y_train.to(DEVICE)

            optimizer.zero_grad()

            # Forward pass through the updated CNN
            y_hat = cnn(X_train)
            train_loss = loss_fn(y_hat, y_train)
            train_loss.backward()
            optimizer.step()

            train_loss_sum += train_loss.item()

        scheduler.step()  # Adjust learning rate

        cnn.eval()  # Set model to evaluation mode
        with torch.no_grad():
            val_accuracy_sum = 0
            val_loss_sum = 0

            for X_val, y_val in val_loader:
                X_val = X_val.to(DEVICE)
                y_val = y_val.to(DEVICE)

                # Forward pass during validation
                y_hat = cnn(X_val)

                val_accuracy_sum += (torch.argmax(y_hat, dim=1) == y_val).float().mean()
                val_loss_sum += loss_fn(y_hat, y_val)

            val_loss = (val_loss_sum / len(val_loader)).cpu()
            val_accuracy = (val_accuracy_sum / len(val_loader)).cpu()

            # Early stopping logic
            if val_loss < best_val_loss:
                best_val_loss = val_loss
                patience_counter = 0
            else:
                patience_counter += 1
                if patience_counter >= early_stopping_patience:
                    print(f"Early stopping triggered for learning rate {lr}.")
                    break

            # Update metrices
            cnn_metrics[lr]["accuracies"].append(val_accuracy.item())
            cnn_metrics[lr]["losses"].append(val_loss.item())

        # Logging information
        print(f"LR = {lr} --- EPOCH = {epoch + 1}")
        print(f"Training loss = {train_loss_sum / len(train_loader):.4f}")
        print(f"Validation loss = {val_loss:.4f} --- Validation accuracy = {val_accuracy:.4f}")
# Out:
# LR = 0.0005 --- EPOCH = 1
# Training loss = 1.0775
# Validation loss = 1.0971 --- Validation accuracy = 0.3989
# LR = 0.0005 --- EPOCH = 2
# Training loss = 1.0506
# Validation loss = 1.0362 --- Validation accuracy = 0.4890
# LR = 0.0005 --- EPOCH = 3
# Training loss = 1.0277
# Validation loss = 1.0554 --- Validation accuracy = 0.4771
# LR = 0.0005 --- EPOCH = 4
# Training loss = 1.0113
# Validation loss = 1.0627 --- Validation accuracy = 0.4633
# LR = 0.0005 --- EPOCH = 5
# Training loss = 0.9334
# Validation loss = 0.9681 --- Validation accuracy = 0.5660
# LR = 0.0005 --- EPOCH = 6
# Training loss = 0.9254
# Validation loss = 0.9204 --- Validation accuracy = 0.6153
# LR = 0.0005 --- EPOCH = 7
# Training loss = 0.9088
# Validation loss = 1.0789 --- Validation accuracy = 0.4546
# LR = 0.0005 --- EPOCH = 8
# Training loss = 0.8941
# Validation loss = 0.8889 --- Validation accuracy = 0.6529
# LR = 0.0005 --- EPOCH = 9
# Training loss = 0.8619
# Validation loss = 0.9016 --- Validation accuracy = 0.6254
# LR = 0.0005 --- EPOCH = 10
# Training loss = 0.8385
# Validation loss = 0.8563 --- Validation accuracy = 0.6879
# LR = 0.0005 --- EPOCH = 11
# Training loss = 0.8217
# Validation loss = 0.8508 --- Validation accuracy = 0.7024
# LR = 0.0005 --- EPOCH = 12
# Training loss = 0.8400
# Validation loss = 0.8736 --- Validation accuracy = 0.6692
# LR = 0.0005 --- EPOCH = 13
# Training loss = 0.8231
# Validation loss = 0.8583 --- Validation accuracy = 0.6911
# LR = 0.0005 --- EPOCH = 14
# Training loss = 0.8122
# Validation loss = 0.8459 --- Validation accuracy = 0.7061
# LR = 0.0005 --- EPOCH = 15
# Training loss = 0.8209
# Validation loss = 0.8465 --- Validation accuracy = 0.7017
# LR = 0.0005 --- EPOCH = 16
# Training loss = 0.8097
# Validation loss = 0.8446 --- Validation accuracy = 0.7004
# LR = 0.0005 --- EPOCH = 17
# Training loss = 0.7908
# Validation loss = 0.8437 --- Validation accuracy = 0.7024
# LR = 0.0005 --- EPOCH = 18
# Training loss = 0.8110
# Validation loss = 0.8434 --- Validation accuracy = 0.6967
# LR = 0.0005 --- EPOCH = 19
# Training loss = 0.7983
# Validation loss = 0.8421 --- Validation accuracy = 0.7067
# LR = 0.0005 --- EPOCH = 20
# Training loss = 0.8083
# Validation loss = 0.8428 --- Validation accuracy = 0.6992
# LR = 0.0004 --- EPOCH = 1
# Training loss = 1.0862
# Validation loss = 1.0647 --- Validation accuracy = 0.4601
# LR = 0.0004 --- EPOCH = 2
# Training loss = 1.0346
# Validation loss = 1.0439 --- Validation accuracy = 0.4808
# LR = 0.0004 --- EPOCH = 3
# Training loss = 1.0451
# Validation loss = 1.0379 --- Validation accuracy = 0.4983
# LR = 0.0004 --- EPOCH = 4
# Training loss = 1.0463
# Validation loss = 1.0372 --- Validation accuracy = 0.5058
# LR = 0.0004 --- EPOCH = 5
# Training loss = 1.0178
# Validation loss = 1.0229 --- Validation accuracy = 0.5196
# LR = 0.0004 --- EPOCH = 6
# Training loss = 0.9848
# Validation loss = 1.0141 --- Validation accuracy = 0.5253
# LR = 0.0004 --- EPOCH = 7
# Training loss = 0.9727
# Validation loss = 1.1151 --- Validation accuracy = 0.3801
# LR = 0.0004 --- EPOCH = 8
# Training loss = 1.0198
# Validation loss = 1.0349 --- Validation accuracy = 0.5083
# LR = 0.0004 --- EPOCH = 9
# Training loss = 0.9907
# Validation loss = 1.0141 --- Validation accuracy = 0.5258
# LR = 0.0004 --- EPOCH = 10
# Training loss = 0.9778
# Validation loss = 1.0063 --- Validation accuracy = 0.5340
# LR = 0.0004 --- EPOCH = 11
# Training loss = 0.9659
# Validation loss = 1.0021 --- Validation accuracy = 0.5296
# LR = 0.0004 --- EPOCH = 12
# Training loss = 0.9546
# Validation loss = 0.9628 --- Validation accuracy = 0.5578
# LR = 0.0004 --- EPOCH = 13
# Training loss = 0.9111
# Validation loss = 0.9381 --- Validation accuracy = 0.5854
# LR = 0.0004 --- EPOCH = 14
# Training loss = 0.9016
# Validation loss = 0.9325 --- Validation accuracy = 0.5942
# LR = 0.0004 --- EPOCH = 15
# Training loss = 0.8814
# Validation loss = 0.9314 --- Validation accuracy = 0.5972
# LR = 0.0004 --- EPOCH = 16
# Training loss = 0.8772
# Validation loss = 0.9208 --- Validation accuracy = 0.6110
# LR = 0.0004 --- EPOCH = 17
# Training loss = 0.8742
# Validation loss = 0.9179 --- Validation accuracy = 0.6179
# LR = 0.0004 --- EPOCH = 18
# Training loss = 0.8535
# Validation loss = 0.9174 --- Validation accuracy = 0.6197
# LR = 0.0004 --- EPOCH = 19
# Training loss = 0.8626
# Validation loss = 0.9174 --- Validation accuracy = 0.6192
# LR = 0.0004 --- EPOCH = 20
# Training loss = 0.8613
# Validation loss = 0.9175 --- Validation accuracy = 0.6185
# LR = 0.0003 --- EPOCH = 1
# Training loss = 1.1001
# Validation loss = 1.0663 --- Validation accuracy = 0.4533
# LR = 0.0003 --- EPOCH = 2
# Training loss = 1.0524
# Validation loss = 1.0655 --- Validation accuracy = 0.4626
# LR = 0.0003 --- EPOCH = 3
# Training loss = 1.0303
# Validation loss = 1.0441 --- Validation accuracy = 0.4808
# LR = 0.0003 --- EPOCH = 4
# Training loss = 1.0195
# Validation loss = 1.0249 --- Validation accuracy = 0.5046
# LR = 0.0003 --- EPOCH = 5
# Training loss = 1.0120
# Validation loss = 1.0187 --- Validation accuracy = 0.5228
# LR = 0.0003 --- EPOCH = 6
# Training loss = 1.0015
# Validation loss = 1.0253 --- Validation accuracy = 0.5096
# LR = 0.0003 --- EPOCH = 7
# Training loss = 1.0083
# Validation loss = 1.0143 --- Validation accuracy = 0.5253
# LR = 0.0003 --- EPOCH = 8
# Training loss = 0.9822
# Validation loss = 1.0013 --- Validation accuracy = 0.5283
# LR = 0.0003 --- EPOCH = 9
# Training loss = 0.9418
# Validation loss = 0.9771 --- Validation accuracy = 0.5503
# LR = 0.0003 --- EPOCH = 10
# Training loss = 0.9443
# Validation loss = 0.9768 --- Validation accuracy = 0.5458
# LR = 0.0003 --- EPOCH = 11
# Training loss = 0.9297
# Validation loss = 0.9624 --- Validation accuracy = 0.5835
# LR = 0.0003 --- EPOCH = 12
# Training loss = 0.9323
# Validation loss = 0.9551 --- Validation accuracy = 0.5872
# LR = 0.0003 --- EPOCH = 13
# Training loss = 0.9288
# Validation loss = 0.9492 --- Validation accuracy = 0.6029
# LR = 0.0003 --- EPOCH = 14
# Training loss = 0.9162
# Validation loss = 0.9498 --- Validation accuracy = 0.5810
# LR = 0.0003 --- EPOCH = 15
# Training loss = 0.8973
# Validation loss = 0.9369 --- Validation accuracy = 0.6161
# LR = 0.0003 --- EPOCH = 16
# Training loss = 0.8855
# Validation loss = 0.9316 --- Validation accuracy = 0.6167
# LR = 0.0003 --- EPOCH = 17
# Training loss = 0.8781
# Validation loss = 0.9298 --- Validation accuracy = 0.6274
# LR = 0.0003 --- EPOCH = 18
# Training loss = 0.8741
# Validation loss = 0.9282 --- Validation accuracy = 0.6324
# LR = 0.0003 --- EPOCH = 19
# Training loss = 0.8718
# Validation loss = 0.9276 --- Validation accuracy = 0.6311
# LR = 0.0003 --- EPOCH = 20
# Training loss = 0.8762
# Validation loss = 0.9271 --- Validation accuracy = 0.6361
# LR = 0.0002 --- EPOCH = 1
# Training loss = 1.0820
# Validation loss = 1.0579 --- Validation accuracy = 0.4528
# LR = 0.0002 --- EPOCH = 2
# Training loss = 1.0050
# Validation loss = 1.0384 --- Validation accuracy = 0.4772
# LR = 0.0002 --- EPOCH = 3
# Training loss = 0.9741
# Validation loss = 0.9824 --- Validation accuracy = 0.5215
# LR = 0.0002 --- EPOCH = 4
# Training loss = 0.9517
# Validation loss = 0.9752 --- Validation accuracy = 0.5385
# LR = 0.0002 --- EPOCH = 5
# Training loss = 0.9146
# Validation loss = 0.9401 --- Validation accuracy = 0.6147
# LR = 0.0002 --- EPOCH = 6
# Training loss = 0.9149
# Validation loss = 0.9922 --- Validation accuracy = 0.5410
# LR = 0.0002 --- EPOCH = 7
# Training loss = 0.8800
# Validation loss = 0.9059 --- Validation accuracy = 0.6586
# LR = 0.0002 --- EPOCH = 8
# Training loss = 0.8604
# Validation loss = 0.9169 --- Validation accuracy = 0.6185
# LR = 0.0002 --- EPOCH = 9
# Training loss = 0.8488
# Validation loss = 0.8927 --- Validation accuracy = 0.6642
# LR = 0.0002 --- EPOCH = 10
# Training loss = 0.8294
# Validation loss = 0.8922 --- Validation accuracy = 0.6597
# LR = 0.0002 --- EPOCH = 11
# Training loss = 0.8123
# Validation loss = 0.8876 --- Validation accuracy = 0.6597
# LR = 0.0002 --- EPOCH = 12
# Training loss = 0.8162
# Validation loss = 0.8855 --- Validation accuracy = 0.6585
# LR = 0.0002 --- EPOCH = 13
# Training loss = 0.8167
# Validation loss = 0.8820 --- Validation accuracy = 0.6642
# LR = 0.0002 --- EPOCH = 14
# Training loss = 0.8211
# Validation loss = 0.8812 --- Validation accuracy = 0.6679
# LR = 0.0002 --- EPOCH = 15
# Training loss = 0.8120
# Validation loss = 0.8816 --- Validation accuracy = 0.6692
# LR = 0.0002 --- EPOCH = 16
# Training loss = 0.8016
# Validation loss = 0.8796 --- Validation accuracy = 0.6672
# LR = 0.0002 --- EPOCH = 17
# Training loss = 0.7983
# Validation loss = 0.8778 --- Validation accuracy = 0.6685
# LR = 0.0002 --- EPOCH = 18
# Training loss = 0.8009
# Validation loss = 0.8780 --- Validation accuracy = 0.6672
# LR = 0.0002 --- EPOCH = 19
# Training loss = 0.8003
# Validation loss = 0.8782 --- Validation accuracy = 0.6685
# LR = 0.0002 --- EPOCH = 20
# Training loss = 0.8124
# Validation loss = 0.8776 --- Validation accuracy = 0.6672
# LR = 0.0001 --- EPOCH = 1
# Training loss = 1.0869
# Validation loss = 1.0648 --- Validation accuracy = 0.4464
# LR = 0.0001 --- EPOCH = 2
# Training loss = 1.0268
# Validation loss = 1.0339 --- Validation accuracy = 0.4985
# LR = 0.0001 --- EPOCH = 3
# Training loss = 1.0069
# Validation loss = 1.0073 --- Validation accuracy = 0.5254
# LR = 0.0001 --- EPOCH = 4
# Training loss = 0.9897
# Validation loss = 0.9913 --- Validation accuracy = 0.5735
# LR = 0.0001 --- EPOCH = 5
# Training loss = 0.9847
# Validation loss = 0.9969 --- Validation accuracy = 0.5472
# LR = 0.0001 --- EPOCH = 6
# Training loss = 0.9611
# Validation loss = 0.9634 --- Validation accuracy = 0.5792
# LR = 0.0001 --- EPOCH = 7
# Training loss = 0.9309
# Validation loss = 0.9613 --- Validation accuracy = 0.5629
# LR = 0.0001 --- EPOCH = 8
# Training loss = 0.9172
# Validation loss = 0.9422 --- Validation accuracy = 0.6104
# LR = 0.0001 --- EPOCH = 9
# Training loss = 0.9031
# Validation loss = 0.9363 --- Validation accuracy = 0.6286
# LR = 0.0001 --- EPOCH = 10
# Training loss = 0.8948
# Validation loss = 0.9352 --- Validation accuracy = 0.6324
# LR = 0.0001 --- EPOCH = 11
# Training loss = 0.8906
# Validation loss = 0.9304 --- Validation accuracy = 0.6292
# LR = 0.0001 --- EPOCH = 12
# Training loss = 0.8882
# Validation loss = 0.9294 --- Validation accuracy = 0.6411
# LR = 0.0001 --- EPOCH = 13
# Training loss = 0.8857
# Validation loss = 0.9275 --- Validation accuracy = 0.6424
# LR = 0.0001 --- EPOCH = 14
# Training loss = 0.8802
# Validation loss = 0.9268 --- Validation accuracy = 0.6499
# LR = 0.0001 --- EPOCH = 15
# Training loss = 0.8805
# Validation loss = 0.9249 --- Validation accuracy = 0.6392
# LR = 0.0001 --- EPOCH = 16
# Training loss = 0.8737
# Validation loss = 0.9259 --- Validation accuracy = 0.6424
# LR = 0.0001 --- EPOCH = 17
# Training loss = 0.8682
# Validation loss = 0.9239 --- Validation accuracy = 0.6392
# LR = 0.0001 --- EPOCH = 18
# Training loss = 0.8597
# Validation loss = 0.9243 --- Validation accuracy = 0.6367
# LR = 0.0001 --- EPOCH = 19
# Training loss = 0.8819
# Validation loss = 0.9234 --- Validation accuracy = 0.6379
# LR = 0.0001 --- EPOCH = 20
# Training loss = 0.8780
# Validation loss = 0.9228 --- Validation accuracy = 0.6404

# %%
#Changing plotting for new training
# Validation Accuracy Plot
for lr in lr_values:
    x_axis = list(range(len(cnn_metrics[lr]["accuracies"])))  # Dynamically calculate x-axis length
    plt.plot(x_axis, cnn_metrics[lr]["accuracies"], label=f"Validation accuracy (lr={lr})")

plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Iterations")
plt.legend()
plt.show()

# Validation Loss Plot
for lr in lr_values:
    x_axis = list(range(len(cnn_metrics[lr]["losses"])))  # Dynamically calculate x-axis length
    plt.plot(x_axis, cnn_metrics[lr]["losses"], label=f"Validation loss (lr={lr})")

plt.xlabel("Iteration")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Iterations")
plt.legend()
plt.show()


best_lr = min(lr_values, key=lambda lr: min(cnn_metrics[lr]["losses"]))
best_cnn = cnn_models[best_lr]  # Get the best CNN model

# Evaluate on the test set
test_accuracy_sum = 0
for X_test, y_test in test_loader:
    X_test = X_test.to(DEVICE)
    y_test = y_test.to(DEVICE)
    y_hat = best_cnn(X_test)
    test_accuracy_sum += accuracy(y_hat, y_test)

test_accuracy = (test_accuracy_sum / len(test_loader)).cpu()
print(f"Test set accuracy of best CNN model (lr={best_lr}): {test_accuracy:.4f}")

# Display model complexity
total_params_cnn = sum(param.numel() for param in best_cnn.parameters())
print(f"Number of parameters in CNN: {total_params_cnn}")
# Out:
# Test set accuracy of best CNN model (lr=0.0005): 0.7151
# Number of parameters in CNN: 121827

# %% [markdown]
# # The following is the original model

# %%
#original CNN
class CNN(nn.Module):
    def __init__(self, input_channels=1, num_classes=3):  # context has 3 classes
        super(CNN, self).__init__()

        self.conv1 = nn.Conv2d(in_channels=input_channels, out_channels=5, kernel_size=3, padding="same")
        self.conv2 = nn.Conv2d(in_channels=5, out_channels=10, kernel_size=3, padding="same")
        self.conv3 = nn.Conv2d(in_channels=10, out_channels=20, kernel_size=3, padding="same")

        # For spectrogram shape: (1, 59, 344) → after 3x maxpool2d(2), dims = (20, 7, 43)
        self.flattened_size = 20 * 7 * 43
        self.linear = nn.Linear(self.flattened_size, num_classes)

    def forward(self, x):
        x = self.conv1(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv2(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = self.conv3(x)
        x = F.relu(x)
        x = F.max_pool2d(x, 2)

        x = torch.flatten(x, start_dim=1)
        x = F.softmax(x, dim=1)
        x = self.linear(x)
        return x

# %%
#orginal training
DEVICE = "cuda" if torch.cuda.is_available() else "cpu"
lr_values = [0.01, 0.001, 0.0001]
num_epochs = 10
num_iterations_before_validation = 1000

cnn_metrics = {}
cnn_models = {}

loss_fn = nn.CrossEntropyLoss()

for lr in lr_values:
    cnn_metrics[lr] = {
        "accuracies": [],
        "losses": []
    }

    cnn = CNN().to(DEVICE)
    optimizer = optim.Adam(cnn.parameters(), lr)
    cnn_models[lr] = cnn

    for epoch in range(num_epochs):
        for iteration, (X_train, y_train) in enumerate(train_loader):
            X_train = X_train.to(DEVICE)
            y_train = y_train.to(DEVICE)
            optimizer.zero_grad()
            y_hat = cnn(X_train)
            train_loss = loss_fn(y_hat, y_train)
            train_loss.backward()
            optimizer.step()

            if iteration == len(train_loader) - 1:

                with torch.no_grad():
                    val_accuracy_sum = 0
                    val_loss_sum = 0
                    for X_val, y_val in val_loader:
                        X_val = X_val.to(DEVICE)
                        y_val = y_val.to(DEVICE)
                        y_hat = cnn(X_val)
                        val_accuracy_sum += accuracy(y_hat, y_val)
                        val_loss_sum += loss_fn(y_hat, y_val)
                    val_accuracy = (val_accuracy_sum / len(val_loader)).cpu()
                    val_loss = (val_loss_sum / len(val_loader)).cpu()
                    cnn_metrics[lr]["accuracies"].append(val_accuracy)
                    cnn_metrics[lr]["losses"].append(val_loss)
                    print(f"LR = {lr} --- EPOCH = {epoch} --- ITERATION = {iteration}")
                    print(f"Validation loss = {val_loss:.4f} --- Validation accuracy = {val_accuracy:.4f}")
# Out:
# LR = 0.01 --- EPOCH = 0 --- ITERATION = 24
# Validation loss = 1.1005 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 1 --- ITERATION = 24
# Validation loss = 1.0974 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 2 --- ITERATION = 24
# Validation loss = 1.0972 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 3 --- ITERATION = 24
# Validation loss = 1.0986 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 4 --- ITERATION = 24
# Validation loss = 1.0975 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 5 --- ITERATION = 24
# Validation loss = 1.0975 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 6 --- ITERATION = 24
# Validation loss = 1.0980 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 7 --- ITERATION = 24
# Validation loss = 1.0993 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 8 --- ITERATION = 24
# Validation loss = 1.0979 --- Validation accuracy = 0.3589
# LR = 0.01 --- EPOCH = 9 --- ITERATION = 24
# Validation loss = 1.0980 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 0 --- ITERATION = 24
# Validation loss = 1.0977 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 1 --- ITERATION = 24
# Validation loss = 1.0968 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 2 --- ITERATION = 24
# Validation loss = 1.0962 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 3 --- ITERATION = 24
# Validation loss = 1.0961 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 4 --- ITERATION = 24
# Validation loss = 1.0956 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 5 --- ITERATION = 24
# Validation loss = 1.0952 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 6 --- ITERATION = 24
# Validation loss = 1.0944 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 7 --- ITERATION = 24
# Validation loss = 1.0934 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 8 --- ITERATION = 24
# Validation loss = 1.0925 --- Validation accuracy = 0.3589
# LR = 0.001 --- EPOCH = 9 --- ITERATION = 24
# Validation loss = 1.0917 --- Validation accuracy = 0.3589
# LR = 0.0001 --- EPOCH = 0 --- ITERATION = 24
# Validation loss = 1.0986 --- Validation accuracy = 0.3396
# LR = 0.0001 --- EPOCH = 1 --- ITERATION = 24
# Validation loss = 1.0984 --- Validation accuracy = 0.3396
# LR = 0.0001 --- EPOCH = 2 --- ITERATION = 24
# Validation loss = 1.0982 --- Validation accuracy = 0.3396
# LR = 0.0001 --- EPOCH = 3 --- ITERATION = 24
# Validation loss = 1.0981 --- Validation accuracy = 0.3396
# LR = 0.0001 --- EPOCH = 4 --- ITERATION = 24
# Validation loss = 1.0980 --- Validation accuracy = 0.3433
# LR = 0.0001 --- EPOCH = 5 --- ITERATION = 24
# Validation loss = 1.0979 --- Validation accuracy = 0.3503
# LR = 0.0001 --- EPOCH = 6 --- ITERATION = 24
# Validation loss = 1.0978 --- Validation accuracy = 0.3946
# LR = 0.0001 --- EPOCH = 7 --- ITERATION = 24
# Validation loss = 1.0977 --- Validation accuracy = 0.3808
# LR = 0.0001 --- EPOCH = 8 --- ITERATION = 24
# Validation loss = 1.0976 --- Validation accuracy = 0.3733
# LR = 0.0001 --- EPOCH = 9 --- ITERATION = 24
# Validation loss = 1.0974 --- Validation accuracy = 0.3721

# %%
#original plotting plus lr 0.0001
x_axis = list(range(len(cnn_metrics[0.01]["accuracies"])))

plt.plot(x_axis, cnn_metrics[0.01]["accuracies"], label="Validation accuracy (lr=0.01)")
plt.plot(x_axis, cnn_metrics[0.001]["accuracies"], label="Validation accuracy (lr=0.001)")
plt.plot(x_axis, cnn_metrics[0.0001]["accuracies"], label="Validation accuracy (lr=0.0001)")
plt.xlabel("Iteration")
plt.ylabel("Validation Accuracy")
plt.title("Validation Accuracy vs Iterations")
plt.legend()
plt.show()

plt.plot(x_axis, cnn_metrics[0.01]["losses"], label="Validation loss (lr=0.01)")
plt.plot(x_axis, cnn_metrics[0.001]["losses"], label="Validation loss (lr=0.001)")
plt.plot(x_axis, cnn_metrics[0.0001]["losses"], label="Validation loss (lr=0.0001)")
plt.xlabel("Iteration")
plt.ylabel("Validation Loss")
plt.title("Validation Loss vs Iterations")
plt.legend()
plt.show()

test_accuracy_sum = 0
best_cnn = cnn_models[0.001]

for X_test, y_test in test_loader:
    X_test = X_test.to(DEVICE)
    y_test = y_test.to(DEVICE)
    y_hat = best_cnn(X_test)
    test_accuracy_sum += accuracy(y_hat, y_test)

test_accuracy = (test_accuracy_sum / len(test_loader)).cpu()
print(f"Test set accuracy of best CNN model: {test_accuracy:.4f}")

total_params_cnn = sum(param.numel() for param in best_cnn.parameters())
print(f"Number of parameters in CNN: {total_params_cnn}")
# Out:
# Test set accuracy of best CNN model: 0.3558
# Number of parameters in CNN: 20393
